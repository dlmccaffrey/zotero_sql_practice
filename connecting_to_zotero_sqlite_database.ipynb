# %% [markdown]
# # Learning SQL by analyzing my Zotero database
# Zotero is a reference manager that I use to organize all my academic references, such as journal articles. It is similar to Endnote or Mendeley. It turns out that the database is stored in a SQLite database. I'm going to practice SQL by analyzing some of the stats about my citations.

# %%
import sqlite3
import pprint

# %%
zotero = sqlite3.connect('zotero.sqlite')

# %%
cur = zotero.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
tables = cur.fetchall()
tables
# Out:
# [('annotations',),
#  ('baseFieldMappings',),
#  ('baseFieldMappingsCombined',),
#  ('charsets',),
#  ('collectionItems',),
#  ('collections',),
#  ('creatorData',),
#  ('creatorTypes',),
#  ('creators',),
#  ('customBaseFieldMappings',),
#  ('customFields',),
#  ('customItemTypeFields',),
#  ('customItemTypes',),
#  ('deletedItems',),
#  ('fieldFormats',),
#  ('fields',),
#  ('fieldsCombined',),
#  ('fileTypeMimeTypes',),
#  ('fileTypes',),
#  ('fulltextItemWords',),
#  ('fulltextItems',),
#  ('fulltextWords',),
#  ('groupItems',),
#  ('groups',),
#  ('highlights',),
#  ('itemAttachments',),
#  ('itemCreators',),
#  ('itemData',),
#  ('itemDataValues',),
#  ('itemNotes',),
#  ('itemSeeAlso',),
#  ('itemTags',),
#  ('itemTypeCreatorTypes',),
#  ('itemTypeFields',),
#  ('itemTypeFieldsCombined',),
#  ('itemTypes',),
#  ('itemTypesCombined',),
#  ('items',),
#  ('libraries',),
#  ('proxies',),
#  ('proxyHosts',),
#  ('relations',),
#  ('savedSearchConditions',),
#  ('savedSearches',),
#  ('settings',),
#  ('storageDeleteLog',),
#  ('syncDeleteLog',),
#  ('syncObjectTypes',),
#  ('syncedSettings',),
#  ('tags',),
#  ('transactionLog',),
#  ('transactionSets',),
#  ('transactions',),
#  ('translatorCache',),
#  ('users',),
#  ('version',),
#  ('zoteroDummyTable',)]

# %%
cur.execute("SELECT * FROM libraries LIMIT 1")
libraries_exploring = cur.fetchall()
print(libraries_exploring)
cur.description
#This table is empty.
# Out:
# []
# (('libraryID', None, None, None, None, None, None),
#  ('libraryType', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM tags LIMIT 1")
tags_exploring = cur.fetchall()
print(tags_exploring)
cur.description
#This is the custom tags that I give my references. Looks like the actual tag is the 2nd element in the tuple.
# Out:
# [(1, 'trioxacyclononane conformational space mol mechanic DFT', 0, '2010-05-27 16:27:27', '2010-05-27 16:27:27', '2010-05-27 16:27:27', None, 'RWNKAI87')]
# (('tagID', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('type', None, None, None, None, None, None),
#  ('dateAdded', None, None, None, None, None, None),
#  ('dateModified', None, None, None, None, None, None),
#  ('clientDateModified', None, None, None, None, None, None),
#  ('libraryID', None, None, None, None, None, None),
#  ('key', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM items LIMIT 1")
items_exploring = cur.fetchall()
print(items_exploring)
cur.description
#I'm thinking this is a table of all my citations with ID only. The key looks like the randomized name
#it gives the file storage folders.
# Out:
# [(1, 1, '2011-04-08 20:56:27', '2011-04-08 20:56:31', '2011-04-08 20:56:31', None, 'I55GBI6K')]
# (('itemID', None, None, None, None, None, None),
#  ('itemTypeID', None, None, None, None, None, None),
#  ('dateAdded', None, None, None, None, None, None),
#  ('dateModified', None, None, None, None, None, None),
#  ('clientDateModified', None, None, None, None, None, None),
#  ('libraryID', None, None, None, None, None, None),
#  ('key', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM itemTypes LIMIT 1")
itemTypes_exploring = cur.fetchall()
print(itemTypes_exploring)
cur.description
# Out:
# [(1, 'note', None, 0)]
# (('itemTypeID', None, None, None, None, None, None),
#  ('typeName', None, None, None, None, None, None),
#  ('templateItemTypeID', None, None, None, None, None, None),
#  ('display', None, None, None, None, None, None))

# %%
cur.execute("SELECT typeName FROM itemTypes")
itemTypes_exploring2 = cur.fetchall()
itemTypes_exploring2
#So this is all the types. These are more like classes. I'm looking for the instances.
# Out:
# [('note',),
#  ('book',),
#  ('bookSection',),
#  ('journalArticle',),
#  ('magazineArticle',),
#  ('newspaperArticle',),
#  ('thesis',),
#  ('letter',),
#  ('manuscript',),
#  ('interview',),
#  ('film',),
#  ('artwork',),
#  ('webpage',),
#  ('attachment',),
#  ('report',),
#  ('bill',),
#  ('case',),
#  ('hearing',),
#  ('patent',),
#  ('statute',),
#  ('email',),
#  ('map',),
#  ('blogPost',),
#  ('instantMessage',),
#  ('forumPost',),
#  ('audioRecording',),
#  ('presentation',),
#  ('videoRecording',),
#  ('tvBroadcast',),
#  ('radioBroadcast',),
#  ('podcast',),
#  ('computerProgram',),
#  ('conferencePaper',),
#  ('document',),
#  ('encyclopediaArticle',),
#  ('dictionaryEntry',)]

# %%
cur.execute("SELECT * FROM itemDataValues LIMIT 10")
itemDataValues_exploring = cur.fetchall()
pprint.pprint(itemDataValues_exploring)
cur.description
#Here's the data. Each piece of data seems to get its own itemID because several citations are represented here.
# Out:
# [(1,
#   'Cooperative hydrophobic/hydrophilic interactions in the hydration of '
#   'dimethyl ether'),
#  (2, '2010-04-21 April 21, 2010'),
#  (3,
#   'Copyright (C) 2010 American Chemical Society (ACS). All Rights Reserved.'),
#  (4, '1999-00-00 1999'),
#  (5,
#   'Searching the Conformational Space of Cyclic Molecules: A Molecular '
#   'Mechanics and Density Functional Theory Study of 9-Crown-3.'),
#  (6,
#   'The conformational space of 1,4,7-trioxacyclononane (9-crown-3) was studied '
#   'using Conflex-AMBER and ab initio calcns. at the d. functional level of '
#   'theory (DFT). The Conflex-AMBER calcns. predict that the [225]100 '
#   'conformation with C2 symmetry is the global min. with the [144]0 '
#   'conformation being 0.9 kcal mol-1 above the global min. and these two '
#   'conformations exist in a deep conformational well. The next lowest energy '
#   'structure is 3.3 kcal mol-1 above the global min. The DFT studies show that '
#   'the stability order is inverted. The C2 symmetry conformation [225]100 is '
#   '0.9 kcal mol-1 higher in energy than the global min. [144]0 conformation '
#   'and the next lowest energy conformer is 4.8 kcal mol-1 above the global '
#   'min. The study highlights the flexibility of 9-crown-3 and the suitability '
#   'of Conflex-AMBER program for conformational space searching of macrocyclic '
#   'ligands. [on SciFinder(R)]'),
#  (7, 'J. Phys. Chem. A'),
#  (8, 'Journal of Physical Chemistry A'),
#  (9, 103),
#  (10, 50)]
# (('valueID', None, None, None, None, None, None),
#  ('value', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM itemData LIMIT 3")
itemData_exploring = cur.fetchall()
pprint.pprint(itemData_exploring)
cur.description
#This table seems to connect the data values to the item. Need to find fieldID and see what that represents.
# Out:
# [(4, 22, 3), (4, 14, 4), (4, 110, 5)]
# (('itemID', None, None, None, None, None, None),
#  ('fieldID', None, None, None, None, None, None),
#  ('valueID', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM fields LIMIT 3")
fields_exploring = cur.fetchall()
pprint.pprint(fields_exploring)
cur.description
#This tells me what all the fields are.
# Out:
# [(1, 'url', None), (2, 'rights', None), (3, 'series', None)]
# (('fieldID', None, None, None, None, None, None),
#  ('fieldName', None, None, None, None, None, None),
#  ('fieldFormatID', None, None, None, None, None, None))

# %% [markdown]
# Citations are stored in the `items` table with an `itemID`, data is stored in the `itemDataValues` table with a `valueID`, and the field types are stored in the `fields` table with a `fieldID`. The three IDs are crossreferenced in the `itemData` table.

# %%
cur.execute("SELECT fieldName FROM fields ORDER BY fieldName")
field_names = cur.fetchall()
field_names
# Out:
# [('DOI',),
#  ('ISBN',),
#  ('ISSN',),
#  ('abstractNote',),
#  ('accessDate',),
#  ('applicationNumber',),
#  ('archive',),
#  ('archiveLocation',),
#  ('artworkMedium',),
#  ('artworkSize',),
#  ('assignee',),
#  ('audioFileType',),
#  ('audioRecordingFormat',),
#  ('billNumber',),
#  ('blogTitle',),
#  ('bookTitle',),
#  ('callNumber',),
#  ('caseName',),
#  ('code',),
#  ('codeNumber',),
#  ('codePages',),
#  ('codeVolume',),
#  ('committee',),
#  ('company',),
#  ('conferenceName',),
#  ('country',),
#  ('court',),
#  ('date',),
#  ('dateDecided',),
#  ('dateEnacted',),
#  ('dictionaryTitle',),
#  ('distributor',),
#  ('docketNumber',),
#  ('documentNumber',),
#  ('edition',),
#  ('encyclopediaTitle',),
#  ('episodeNumber',),
#  ('extra',),
#  ('filingDate',),
#  ('firstPage',),
#  ('forumTitle',),
#  ('genre',),
#  ('history',),
#  ('institution',),
#  ('interviewMedium',),
#  ('issue',),
#  ('issueDate',),
#  ('issuingAuthority',),
#  ('journalAbbreviation',),
#  ('label',),
#  ('language',),
#  ('legalStatus',),
#  ('legislativeBody',),
#  ('letterType',),
#  ('libraryCatalog',),
#  ('manuscriptType',),
#  ('mapType',),
#  ('medium',),
#  ('meetingName',),
#  ('nameOfAct',),
#  ('network',),
#  ('numPages',),
#  ('number',),
#  ('numberOfVolumes',),
#  ('pages',),
#  ('patentNumber',),
#  ('place',),
#  ('postType',),
#  ('presentationType',),
#  ('priorityNumbers',),
#  ('proceedingsTitle',),
#  ('programTitle',),
#  ('programmingLanguage',),
#  ('publicLawNumber',),
#  ('publicationTitle',),
#  ('publisher',),
#  ('references',),
#  ('reportNumber',),
#  ('reportType',),
#  ('reporter',),
#  ('reporterVolume',),
#  ('rights',),
#  ('runningTime',),
#  ('scale',),
#  ('section',),
#  ('series',),
#  ('seriesNumber',),
#  ('seriesText',),
#  ('seriesTitle',),
#  ('session',),
#  ('shortTitle',),
#  ('studio',),
#  ('subject',),
#  ('system',),
#  ('thesisType',),
#  ('title',),
#  ('type',),
#  ('university',),
#  ('url',),
#  ('version',),
#  ('videoRecordingFormat',),
#  ('volume',),
#  ('websiteTitle',),
#  ('websiteType',)]

# %%
#want to get the fields and values for the first 10 items by joining
cur.execute("SELECT * "
            "FROM itemData t1 "
            "LEFT JOIN fields t2 "
            "ON t1.fieldID = t2.fieldID "
            "LEFT JOIN itemDataValues t3 "
            "ON t1.valueID = t3.valueID "
            "WHERE t1.itemID < 11 ")
items_and_fields_test = cur.fetchall()
pprint.pprint(items_and_fields_test)
cur.description
# Out:
# [(4, 4, 9, 4, 'volume', None, 9, 103),
#  (4, 5, 10, 5, 'issue', None, 10, 50),
#  (4, 10, 11, 10, 'pages', None, 11, '10993-10997'),
#  (4, 12, 8, 12, 'publicationTitle', None, 8, 'Journal of Physical Chemistry A'),
#  (4, 13, 12, 13, 'ISSN', None, 12, '1089-5639'),
#  (4, 14, 4, 14, 'date', None, 4, '1999-00-00 1999'),
#  (4,
#   22,
#   3,
#   22,
#   'extra',
#   None,
#   3,
#   'Copyright (C) 2010 American Chemical Society (ACS). All Rights Reserved.'),
#  (4, 25, 7, 25, 'journalAbbreviation', None, 7, 'J. Phys. Chem. A'),
#  (4,
#   90,
#   6,
#   90,
#   'abstractNote',
#   None,
#   6,
#   'The conformational space of 1,4,7-trioxacyclononane (9-crown-3) was studied '
#   'using Conflex-AMBER and ab initio calcns. at the d. functional level of '
#   'theory (DFT). The Conflex-AMBER calcns. predict that the [225]100 '
#   'conformation with C2 symmetry is the global min. with the [144]0 '
#   'conformation being 0.9 kcal mol-1 above the global min. and these two '
#   'conformations exist in a deep conformational well. The next lowest energy '
#   'structure is 3.3 kcal mol-1 above the global min. The DFT studies show that '
#   'the stability order is inverted. The C2 symmetry conformation [225]100 is '
#   '0.9 kcal mol-1 higher in energy than the global min. [144]0 conformation '
#   'and the next lowest energy conformer is 4.8 kcal mol-1 above the global '
#   'min. The study highlights the flexibility of 9-crown-3 and the suitability '
#   'of Conflex-AMBER program for conformational space searching of macrocyclic '
#   'ligands. [on SciFinder(R)]'),
#  (4,
#   110,
#   5,
#   110,
#   'title',
#   None,
#   5,
#   'Searching the Conformational Space of Cyclic Molecules: A Molecular '
#   'Mechanics and Density Functional Theory Study of 9-Crown-3.'),
#  (8, 4, 24, 4, 'volume', None, 24, 49),
#  (8, 5, 25, 5, 'issue', None, 25, 19),
#  (8, 10, 26, 10, 'pages', None, 26, '3959-70'),
#  (8, 12, 23, 12, 'publicationTitle', None, 23, 'Tetrahedron'),
#  (8, 13, 27, 13, 'ISSN', None, 27, '0040-4020'),
#  (8, 14, 20, 14, 'date', None, 20, '1993-00-00 1993'),
#  (8,
#   22,
#   3,
#   22,
#   'extra',
#   None,
#   3,
#   'Copyright (C) 2010 American Chemical Society (ACS). All Rights Reserved.'),
#  (8, 25, 23, 25, 'journalAbbreviation', None, 23, 'Tetrahedron'),
#  (8,
#   90,
#   22,
#   90,
#   'abstractNote',
#   None,
#   22,
#   'A systematic investigation of the cyclic ethers and amines was conducted '
#   'using MO calcns. to assess their possibility as building blocks of novel '
#   'functional mols. A method was developed to quant. calc. the Free-O- and '
#   'Comp-O radii which correspond to the hole sizes of free and complexed crown '
#   'compds. These radii show the linear relationship with the no. of atoms in '
#   'crown ring for both calcd. and obsd. coordinates. On the other hand, the '
#   'Li-X (X = O and N) lengths are not dependent on the no. of atoms in the '
#   "crown ring. While the ΔEstab's of the crown ethers show a clear dependence "
#   'on the no. of the crown ring atoms, the values does not vary significantly '
#   'among the cyclic amines. The MNDO method gave reasonable results by chance. '
#   '[on SciFinder(R)]'),
#  (8,
#   110,
#   21,
#   110,
#   'title',
#   None,
#   21,
#   'Theoretical study on crown compounds as building blocks of functional '
#   'molecules. I. The relation between the hole size and the number of atoms in '
#   'the ring of cyclic ethers and amines.'),
#  (10, 4, 33, 4, 'volume', None, 33, 134),
#  (10, 5, 34, 5, 'issue', None, 34, 1),
#  (10, 10, 35, 10, 'pages', None, 35, '49-52'),
#  (10, 12, 32, 12, 'publicationTitle', None, 32, 'Inorganica Chimica Acta'),
#  (10, 13, 36, 13, 'ISSN', None, 36, '0020-1693'),
#  (10, 14, 28, 14, 'date', None, 28, '1987-00-00 1987'),
#  (10,
#   22,
#   3,
#   22,
#   'extra',
#   None,
#   3,
#   'Copyright (C) 2010 American Chemical Society (ACS). All Rights Reserved.'),
#  (10, 25, 31, 25, 'journalAbbreviation', None, 31, 'Inorg. Chim. Acta'),
#  (10,
#   90,
#   30,
#   90,
#   'abstractNote',
#   None,
#   30,
#   'The reaction of cis-benzenetrioxid with mono- and bivalent cations was '
#   'measured by calorimetric titrns. in MeOH solns. These measurements show a '
#   'distinct reaction between this ligand and Ba2+. Stability consts. for Ca2+, '
#   'Sr2+, and Ba2+ were obtained by NMR. Only the formation of the Ba2+ complex '
#   'produces enough heat for studying this reaction by calorimetric titrns. in '
#   'other solvents. Therefore, the reactions between the Ba2+ cation and '
#   'cis-benzenetrioxid, 9-crown-3, and 12-crown-4 were studied. From the '
#   'reaction enthalpies measured for the formation of 1:1 and X:1 complexes '
#   '(ratio of ligand to cation) conclusions about the complex stoichiometry can '
#   'be drawn. [on SciFinder(R)]'),
#  (10,
#   110,
#   29,
#   110,
#   'title',
#   None,
#   29,
#   'cis-Benzenetrioxid, 9-crown-3 and 12-crown-4 as ligands for the '
#   'complexation of cations in different solvents.')]
# (('itemID', None, None, None, None, None, None),
#  ('fieldID', None, None, None, None, None, None),
#  ('valueID', None, None, None, None, None, None),
#  ('fieldID', None, None, None, None, None, None),
#  ('fieldName', None, None, None, None, None, None),
#  ('fieldFormatID', None, None, None, None, None, None),
#  ('valueID', None, None, None, None, None, None),
#  ('value', None, None, None, None, None, None))

# %%
#doing the same with more recent entries
cur.execute("SELECT * "
            "FROM itemData t1 "
            "LEFT JOIN fields t2 "
            "ON t1.fieldID = t2.fieldID "
            "LEFT JOIN itemDataValues t3 "
            "ON t1.valueID = t3.valueID "
            "WHERE t1.itemID BETWEEN 100 AND 130 ")
items_and_fields_test2 = cur.fetchall()
pprint.pprint(items_and_fields_test2)
cur.description
# Out:
# [(100, 1, 263, 1, 'url', None, 263, 'http://dx.doi.org/10.1021/ci1000136'),
#  (100, 27, 265, 27, 'accessDate', None, 265, '2010-06-01 16:52:25'),
#  (100, 110, 264, 110, 'title', None, 264, 'ci1000136'),
#  (101,
#   1,
#   266,
#   1,
#   'url',
#   None,
#   266,
#   'http://pubs.acs.org/doi/pdf/10.1021/ci1000136'),
#  (101, 27, 267, 27, 'accessDate', None, 267, '2010-06-01 16:52:45'),
#  (101, 110, 264, 110, 'title', None, 264, 'ci1000136'),
#  (102, 1, 271, 1, 'url', None, 271, 'http://dx.doi.org/10.1002/jrs.2692'),
#  (102, 4, 269, 4, 'volume', None, 269, 9999),
#  (102, 5, 269, 5, 'issue', None, 269, 9999),
#  (102, 10, 270, 10, 'pages', None, 270, 'n/a'),
#  (102,
#   12,
#   86,
#   12,
#   'publicationTitle',
#   None,
#   86,
#   'Journal of Raman Spectroscopy'),
#  (102, 14, 87, 14, 'date', None, 87, '2010-00-00 2010'),
#  (102,
#   90,
#   272,
#   90,
#   'abstractNote',
#   None,
#   272,
#   'A new method has been developed for denoising a spectrum using cubic-spline '
#   'smoothing, which requires no user input or judgement, yet outperforms other '
#   'more conventional algorithms. It relies only on the assumptions that the '
#   'spectrum is sampled at a resolution much higher than the full-width at half '
#   'maximum of any peaks, and that the noise is approximately Gaussian '
#   'distributed, although any other type of noise distribution is acceptable so '
#   'long as the type of distribution is known. Copyright � 2010 John Wiley & '
#   'Sons, Ltd.'),
#  (102,
#   110,
#   268,
#   110,
#   'title',
#   None,
#   268,
#   'Denoising of spectra with no user input: a spline-smoothing algorithm'),
#  (104,
#   1,
#   274,
#   1,
#   'url',
#   None,
#   274,
#   'http://www3.interscience.wiley.com/cgi-bin/fulltext/123476582/PDFSTART'),
#  (104, 27, 276, 27, 'accessDate', None, 276, '2010-06-01 17:10:16'),
#  (104,
#   110,
#   273,
#   110,
#   'title',
#   None,
#   273,
#   'Wiley InterScience :: Journal :: Article PDF'),
#  (105, 1, 282, 1, 'url', None, 282, 'http://dx.doi.org/10.1021/jp102655g'),
#  (105,
#   12,
#   279,
#   12,
#   'publicationTitle',
#   None,
#   279,
#   'The Journal of Physical Chemistry A'),
#  (105, 13, 12, 13, 'ISSN', None, 12, '1089-5639'),
#  (105, 14, 278, 14, 'date', None, 278, '2010-05-25 May 25, 2010'),
#  (105, 26, 281, 26, 'DOI', None, 281, 'doi: 10.1021/jp102655g'),
#  (105,
#   90,
#   280,
#   90,
#   'abstractNote',
#   None,
#   280,
#   'Herein we report an extensive ab initio study on the existence of eight '
#   'β-hydroxy isoprene peroxy radical−water complexes. Binding energies '
#   'calculated at the MP2(full)/6-311++G(2d,2p)//CCSD(T)/6-311++G(d,p) level of '
#   'theory range between 3.85 and 5.66 kcal mol−1. The results of natural bond '
#   'orbital calculations are presented to help rationalize complex formation. '
#   'Atmospheric lifetimes, equilibrium constants, heats of formation, and the '
#   'relative abundance of complexed to uncomplexed peroxy radicals are also '
#   'reported and discussed.'),
#  (105,
#   110,
#   277,
#   110,
#   'title',
#   None,
#   277,
#   'Computational Study of Isoprene Hydroxyalkyl Peroxy Radical−Water Complexes '
#   '(C5H8(OH)O2−H2O)'),
#  (107, 1, 282, 1, 'url', None, 282, 'http://dx.doi.org/10.1021/jp102655g'),
#  (107, 27, 284, 27, 'accessDate', None, 284, '2010-06-01 17:24:58'),
#  (107, 110, 283, 110, 'title', None, 283, 'jp102655g'),
#  (108,
#   1,
#   285,
#   1,
#   'url',
#   None,
#   285,
#   'http://pubs.acs.org/doi/pdf/10.1021/jp102655g'),
#  (108, 27, 286, 27, 'accessDate', None, 286, '2010-06-01 17:25:35'),
#  (108, 110, 283, 110, 'title', None, 283, 'jp102655g'),
#  (109, 1, 291, 1, 'url', None, 291, 'http://dx.doi.org/10.1021/jp1038738'),
#  (109,
#   12,
#   279,
#   12,
#   'publicationTitle',
#   None,
#   279,
#   'The Journal of Physical Chemistry A'),
#  (109, 13, 12, 13, 'ISSN', None, 12, '1089-5639'),
#  (109, 14, 288, 14, 'date', None, 288, '2010-05-24 May 24, 2010'),
#  (109, 26, 290, 26, 'DOI', None, 290, 'doi: 10.1021/jp1038738'),
#  (109,
#   90,
#   289,
#   90,
#   'abstractNote',
#   None,
#   289,
#   'A multilevel extension of the local correlation “cluster-in-molecule” (CIM) '
#   'framework, which enables one to combine different quantum chemistry methods '
#   'to treat different regions in a large molecular system without splitting it '
#   'into ad hoc fragments and saturating dangling bonds, is proposed. The '
#   'resulting schemes combine higher-level methods, such as the completely '
#   'renormalized coupled-cluster (CC) approach with singles, doubles, and '
#   'noniterative triples, termed CR-CC(2,3), to treat the reactive part of a '
#   'large molecular system, and lower-order methods, such as the second-order '
#   'Møller−Plesset perturbation theory (MP2), to handle the chemically inactive '
#   'regions. The multilevel CIM-CC/MP2 approaches preserve the key features of '
#   'all CIM methods, such as the use of orthonormal localized orbitals and '
#   'coarse-grain parallelism, while substantially reducing the already '
#   'relatively low costs of the single-level CIM-CC calculations. Illustrative '
#   'calculations include bond breaking in dodecane and the reactions of the '
#   'bis(2,4,4-trimethylpentyl)dithiophosphinic acid with one and two water '
#   'molecules.'),
#  (109,
#   110,
#   287,
#   110,
#   'title',
#   None,
#   287,
#   'Multilevel Extension of the Cluster-in-Molecule Local Correlation '
#   'Methodology: Merging Coupled-Cluster and Møller−Plesset Perturbation '
#   'Theories'),
#  (111, 1, 291, 1, 'url', None, 291, 'http://dx.doi.org/10.1021/jp1038738'),
#  (111, 27, 293, 27, 'accessDate', None, 293, '2010-06-01 17:28:03'),
#  (111, 110, 292, 110, 'title', None, 292, 'jp1038738'),
#  (112,
#   1,
#   294,
#   1,
#   'url',
#   None,
#   294,
#   'http://pubs.acs.org/doi/pdf/10.1021/jp1038738'),
#  (112, 27, 295, 27, 'accessDate', None, 295, '2010-06-01 17:28:56'),
#  (112, 110, 292, 110, 'title', None, 292, 'jp1038738'),
#  (113, 1, 300, 1, 'url', None, 300, 'http://dx.doi.org/10.1021/ci100049h'),
#  (113,
#   12,
#   259,
#   12,
#   'publicationTitle',
#   None,
#   259,
#   'Journal of Chemical Information and Modeling'),
#  (113, 13, 261, 13, 'ISSN', None, 261, '1549-9596'),
#  (113, 14, 297, 14, 'date', None, 297, '2010-06-04 June 04, 2010'),
#  (113, 26, 299, 26, 'DOI', None, 299, 'doi: 10.1021/ci100049h'),
#  (113,
#   90,
#   298,
#   90,
#   'abstractNote',
#   None,
#   298,
#   'Docking and molecular dynamics (MD) simulations of N1 substituted pyrazole '
#   'derivatives complexed with B-Raf kinase were performed to gain insight into '
#   'the structural and energetic preferences of these inhibitors. First, a '
#   'comparative study of fully automated docking programs AutoDock, ICM, GLIDE, '
#   'and Surflex-Dock in closely approximating the X-ray crystal structure of '
#   'the inhibitor '
#   '(1E)-5-[1-(4-piperidinyl)-3-(4-pyridinyl)-1H-pyrazol-4-yl]-2,3-dihydro-1H-inden-1-one '
#   'oxime was performed. Afterward, the dynamics of the above-mentioned '
#   'compound and the less active analogous compounds with '
#   '1-methyl-4-piperidinyl and tetrahydro-2H-pyran-4-yl groups at position N1 '
#   'of pyrazole ring inside the B-Raf active site were analyzed by MD '
#   'simulations. We found that the most active compound has stable interactions '
#   'with residues Ile463 and His539 at the entrance of the B-Raf active site. '
#   'Those interactions were in very good agreement with more reliable quantum '
#   'mechanics/molecular mechanics calculations performed on the torsional angle '
#   'φ between the pyrazole ring and the substituents at position N1. In '
#   'addition, we identified a water wire connecting N2 of the pyrazole ring, '
#   'Cys532, and Ser536, which is composed of three water molecules for the most '
#   'active compound. We found some differences in the water wire hydrogen-bond '
#   'network formed by less active compounds. We suggest that the differences '
#   'between these structural features are responsible for the differences in '
#   'activity among the studied compounds.'),
#  (113,
#   110,
#   296,
#   110,
#   'title',
#   None,
#   296,
#   'Computational Study on the Interaction of N1 Substituted Pyrazole '
#   'Derivatives with B-Raf Kinase: An Unusual Water Wire Hydrogen-Bond Network '
#   'and Novel Interactions at the Entrance of the Active Site'),
#  (115, 1, 300, 1, 'url', None, 300, 'http://dx.doi.org/10.1021/ci100049h'),
#  (115, 27, 302, 27, 'accessDate', None, 302, '2010-06-07 19:58:02'),
#  (115, 110, 301, 110, 'title', None, 301, 'ci100049h'),
#  (116,
#   1,
#   303,
#   1,
#   'url',
#   None,
#   303,
#   'http://pubs.acs.org/doi/pdf/10.1021/ci100049h'),
#  (116, 27, 304, 27, 'accessDate', None, 304, '2010-06-07 19:58:18'),
#  (116, 110, 301, 110, 'title', None, 301, 'ci100049h'),
#  (118, 1, 309, 1, 'url', None, 309, 'http://dx.doi.org/10.1021/jp1027178'),
#  (118,
#   12,
#   279,
#   12,
#   'publicationTitle',
#   None,
#   279,
#   'The Journal of Physical Chemistry A'),
#  (118, 13, 12, 13, 'ISSN', None, 12, '1089-5639'),
#  (118, 14, 297, 14, 'date', None, 297, '2010-06-04 June 04, 2010'),
#  (118, 26, 308, 26, 'DOI', None, 308, 'doi: 10.1021/jp1027178'),
#  (118,
#   90,
#   307,
#   90,
#   'abstractNote',
#   None,
#   307,
#   'We present a comparative study of proton dissociation in various functional '
#   'acidic units that are promising candidates as building blocks for polymeric '
#   'electrolyte membranes. Minimum energy structures for four acidic moieties '
#   'with clusters of 1−6 water molecules were determined using density '
#   'functional theory at the B3LYP/6-311G** level starting from chemically '
#   'rational initial configurations. The perfluoro sulfonyl imide acid group '
#   '(CF3CF2SO2NHSO2CF3) was observed to be the strongest acid, due to the '
#   'substantial electron withdrawing effect of both fluorocarbon groups. The '
#   'hydrophilic functional group (CH3OC6H3OCH3C6H4SO3H) of sulfonated '
#   'polyetherether ketone (SPEEK) membrane was found to be the strongest base, '
#   'with the acidic proton dissociation requiring the addition of six water '
#   'molecules and the hydrated proton being more tightly bound to the conjugate '
#   'base. Even though both perfluoro sulfonyl imides and sulfonic acids '
#   '(hydrophilic functional groups for sulfonyl imide and Nafion ionomers, '
#   'respectively) required only three water molecules to exhibit spontaneous '
#   'proton dissociation, the largest possible solvent-separated hydronium ion '
#   'was attained only for the sulfonyl imide moiety. These results provide a '
#   'rationale for the enhanced conductivity of perfluorinated sulfonyl '
#   'imide-based membranes relative to that of the widely used Nafion membrane.'),
#  (118,
#   110,
#   306,
#   110,
#   'title',
#   None,
#   306,
#   'Ab Initio Study of Hydration and Proton Dissociation in Ionomer Membranes'),
#  (120, 1, 309, 1, 'url', None, 309, 'http://dx.doi.org/10.1021/jp1027178'),
#  (120, 27, 311, 27, 'accessDate', None, 311, '2010-06-07 20:02:13'),
#  (120, 110, 310, 110, 'title', None, 310, 'jp1027178'),
#  (121,
#   1,
#   312,
#   1,
#   'url',
#   None,
#   312,
#   'http://pubs.acs.org/doi/pdf/10.1021/jp1027178'),
#  (121, 27, 313, 27, 'accessDate', None, 313, '2010-06-07 20:02:18'),
#  (121, 110, 310, 110, 'title', None, 310, 'jp1027178'),
#  (122, 1, 317, 1, 'url', None, 317, 'http://dx.doi.org/10.1021/jp909971f'),
#  (122,
#   12,
#   241,
#   12,
#   'publicationTitle',
#   None,
#   241,
#   'The Journal of Physical Chemistry B'),
#  (122, 13, 243, 13, 'ISSN', None, 243, '1520-6106'),
#  (122, 14, 297, 14, 'date', None, 297, '2010-06-04 June 04, 2010'),
#  (122, 26, 316, 26, 'DOI', None, 316, 'doi: 10.1021/jp909971f'),
#  (122,
#   90,
#   315,
#   90,
#   'abstractNote',
#   None,
#   315,
#   'The β-adrenergic antagonists (β-blockers) constitute a class of drugs that '
#   'have well-established roles in treatments of various cardiovascular '
#   'diseases. Despite a 50 year history, there are two clinically important '
#   'subtypes of β-adrenergic receptors (βARs) called β1AR and β2AR that still '
#   'are promising drug targets. Our study maps the interactions between '
#   'nebivolol―one of the most efficient β-blocking agents―and the β2-adrenergic '
#   'receptor by simulating two optical isomers of nebivolol: ssss-nebivolol and '
#   'srrr-nebivolol. The srrr-configuration binds preferentially to β1AR and '
#   'β2AR. The ssss-form has much lower binding affinity to both of them. Our '
#   'work indicates that water is a very important component of the binding site '
#   'of the β2AR receptor. We found that the higher stereoselectivity of the '
#   'srrr-configuration is due to interactions with water molecules, which '
#   'extensively hydrate the binding site of β2AR. By lowering the energy of '
#   'binding, water enhanced the affinity of the srrr-form to β2AR. We also '
#   'address the problem of β1AR/β2AR selectivity. At higher concentrations, all '
#   'β-blocking agents lose their specificity and bind nonselectively, causing '
#   'many adverse effects. Our simulations indicate that PHE194, TYR308, and '
#   'ILE309 of the β2AR and the corresponding residues of the β1AR receptor may '
#   'be important determinants of β1AR versus β2AR selectivity.'),
#  (122,
#   110,
#   314,
#   110,
#   'title',
#   None,
#   314,
#   'Molecular Dynamics Simulations Reveal Fundamental Role of Water As Factor '
#   'Determining Affinity of Binding of β-Blocker Nebivolol to β2-Adrenergic '
#   'Receptor'),
#  (124, 1, 317, 1, 'url', None, 317, 'http://dx.doi.org/10.1021/jp909971f'),
#  (124, 27, 319, 27, 'accessDate', None, 319, '2010-06-07 20:06:20'),
#  (124, 110, 318, 110, 'title', None, 318, 'jp909971f'),
#  (125,
#   1,
#   320,
#   1,
#   'url',
#   None,
#   320,
#   'http://pubs.acs.org/doi/pdf/10.1021/jp909971f'),
#  (125, 27, 321, 27, 'accessDate', None, 321, '2010-06-07 20:08:16'),
#  (125, 110, 318, 110, 'title', None, 318, 'jp909971f'),
#  (126, 1, 326, 1, 'url', None, 326, 'http://dx.doi.org/10.1021/jp912180d'),
#  (126,
#   12,
#   279,
#   12,
#   'publicationTitle',
#   None,
#   279,
#   'The Journal of Physical Chemistry A'),
#  (126, 13, 12, 13, 'ISSN', None, 12, '1089-5639'),
#  (126, 14, 323, 14, 'date', None, 323, '2010-06-02 June 02, 2010'),
#  (126, 26, 325, 26, 'DOI', None, 325, 'doi: 10.1021/jp912180d'),
#  (126,
#   90,
#   324,
#   90,
#   'abstractNote',
#   None,
#   324,
#   'Attenuated total reflectance-Fourier transform infrared (ATR-FTIR) '
#   'measurements were carried out on the 1-propanol−water (abbreviated as '
#   '1PA−W) mixtures over the entire 1-propanol molar fraction range at 298 K. '
#   'The two bands at ∼1053 and ∼1068 cm−1, assigned to the vibrational modes of '
#   'the gauche (vC−C−C−O−G) and the trans (vC−C−C−O−T) conformational isomers, '
#   'respectively, which both include C−O and C−C stretching motions, were used '
#   'to monitor the structural changes of the mixtures. When the water to '
#   '1-propanol molar ratio (WPR) is smaller than 0.2, the absorbance ratio of '
#   'the two bands (AvC−C−C−O−G/AvC−C−C−O−T) remains constant at 1.42, '
#   'characteristic of the existence of the 1-propanol aggregate chains, '
#   'hydrogen-bonded by the O−H groups of 1-propanol in gauche conformations. '
#   'When increasing the WPR from 0.2 to 20, there is an abrupt decrease in the '
#   'absorbance ratio (AvC−C−C−O−G/AvC−C−C−O−T) from 1.42 to 1.01, corresponding '
#   'to penetration of water molecules into the gauche-aggregate chains. The '
#   'penetrated water molecules disrupt the 1PA chains and transform these '
#   'gauche-aggregate 1PA chains to trans-aggregate chains, which are 1PA dimers '
#   'of trans-conformation. The structural change induces complicated '
#   'spectroscopic changes, including the red shifts of the series of bands '
#   '1016, 1053, and 1098 cm−1 and blue shifts of the bands 2877, 2937, and 2961 '
#   'cm−1. With further increase of WPR up to 100, the absorbance ratio of '
#   'AvC−C−C−O−G/AvC−C−C−O−T increases from 0.98 to 1.07, indicating a '
#   'transformation of partial 1PA dimers to single molecules with '
#   'gauche-conformation in the water hydrogen-bonding network. Together with '
#   'results from quantum calculations at the B3L YP/6-31G (d, p) level, and '
#   'two-dimensional infrared correlation and excess spectroscopy analysis, the '
#   'structural evolution of water and 1PA molecules in 1PA−W mixtures has been '
#   'inferred.'),
#  (126,
#   110,
#   322,
#   110,
#   'title',
#   None,
#   322,
#   'Observation of Conformational Changes in 1-Propanol−Water Complexes by FTIR '
#   'Spectroscopy'),
#  (128, 1, 326, 1, 'url', None, 326, 'http://dx.doi.org/10.1021/jp912180d'),
#  (128, 27, 328, 27, 'accessDate', None, 328, '2010-06-07 20:29:26'),
#  (128, 110, 327, 110, 'title', None, 327, 'jp912180d'),
#  (129,
#   1,
#   329,
#   1,
#   'url',
#   None,
#   329,
#   'http://pubs.acs.org/doi/pdf/10.1021/jp912180d'),
#  (129, 27, 330, 27, 'accessDate', None, 330, '2010-06-07 20:29:39'),
#  (129, 110, 327, 110, 'title', None, 327, 'jp912180d'),
#  (130, 1, 334, 1, 'url', None, 334, 'http://dx.doi.org/10.1021/ja1024113'),
#  (130,
#   12,
#   215,
#   12,
#   'publicationTitle',
#   None,
#   215,
#   'Journal of the American Chemical Society'),
#  (130, 13, 98, 13, 'ISSN', None, 98, '0002-7863'),
#  (130, 14, 323, 14, 'date', None, 323, '2010-06-02 June 02, 2010'),
#  (130, 26, 333, 26, 'DOI', None, 333, 'doi: 10.1021/ja1024113'),
#  (130,
#   90,
#   332,
#   90,
#   'abstractNote',
#   None,
#   332,
#   'The chemical origins of the Hofmeister series are investigated using '
#   'infrared photodissociation (IRPD) spectroscopy. IRPD spectra of SO42−(H2O)n '
#   'with up to 80 water molecules have a band at ∼3710 cm−1 for n > 43 but not '
#   'for n ≤ 43. This band corresponds to outer-shell water molecules with '
#   '“free” OH groups similar to those at the surface of bulk water. These '
#   'results indicate that the sulfate dianion has a long-range effect on water '
#   'structure, and this effect is likely to be an important factor in its '
#   'Hofmeister behavior.'),
#  (130,
#   110,
#   331,
#   110,
#   'title',
#   None,
#   331,
#   'Sulfate Ion Patterns Water at Long Distance')]
# (('itemID', None, None, None, None, None, None),
#  ('fieldID', None, None, None, None, None, None),
#  ('valueID', None, None, None, None, None, None),
#  ('fieldID', None, None, None, None, None, None),
#  ('fieldName', None, None, None, None, None, None),
#  ('fieldFormatID', None, None, None, None, None, None),
#  ('valueID', None, None, None, None, None, None),
#  ('value', None, None, None, None, None, None))

# %% [markdown]
# There isn't author information in this join yet. Need to find where author data is stored.

# %%
cur.execute("SELECT * FROM itemSeeAlso LIMIT 1")
itemSeeAlso_exploring = cur.fetchall()
print(itemSeeAlso_exploring)
cur.description
# Out:
# []
# (('itemID', None, None, None, None, None, None),
#  ('linkedItemID', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM customFields LIMIT 1")
customFields_exploring = cur.fetchall()
print(customFields_exploring)
cur.description
# Out:
# []
# (('customFieldID', None, None, None, None, None, None),
#  ('fieldName', None, None, None, None, None, None),
#  ('label', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM itemCreators LIMIT 1")
itemCreators_exploring = cur.fetchall()
print(itemCreators_exploring)
cur.description
#Looks promising.
# Out:
# [(4, 2, 1, 0)]
# (('itemID', None, None, None, None, None, None),
#  ('creatorID', None, None, None, None, None, None),
#  ('creatorTypeID', None, None, None, None, None, None),
#  ('orderIndex', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM creatorTypes")
creatorTypes_exploring = cur.fetchall()
pprint.pprint(creatorTypes_exploring)
cur.description
#Here is the author 'class'.
# Out:
# [(1, 'author'),
#  (2, 'contributor'),
#  (3, 'editor'),
#  (4, 'translator'),
#  (5, 'seriesEditor'),
#  (6, 'interviewee'),
#  (7, 'interviewer'),
#  (8, 'director'),
#  (9, 'scriptwriter'),
#  (10, 'producer'),
#  (11, 'castMember'),
#  (12, 'sponsor'),
#  (13, 'counsel'),
#  (14, 'inventor'),
#  (15, 'attorneyAgent'),
#  (16, 'recipient'),
#  (17, 'performer'),
#  (18, 'composer'),
#  (19, 'wordsBy'),
#  (20, 'cartographer'),
#  (21, 'programmer'),
#  (22, 'artist'),
#  (23, 'commenter'),
#  (24, 'presenter'),
#  (25, 'guest'),
#  (26, 'podcaster'),
#  (27, 'reviewedAuthor'),
#  (28, 'cosponsor'),
#  (29, 'bookAuthor')]
# (('creatorTypeID', None, None, None, None, None, None),
#  ('creatorType', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM creators LIMIT 3")
creators_exploring = cur.fetchall()
pprint.pprint(creators_exploring)
cur.description
#I think this is the link to the author data.
# Out:
# [(1,
#   1,
#   '2011-05-16 16:46:04',
#   '2011-05-16 16:46:04',
#   '2011-05-16 16:46:04',
#   None,
#   'TG3WNQE9'),
#  (2,
#   2,
#   '2010-05-27 16:27:25',
#   '2010-05-27 16:27:25',
#   '2010-05-27 16:27:25',
#   None,
#   '9F6Q4THW'),
#  (3,
#   3,
#   '2010-05-27 16:27:25',
#   '2010-05-27 16:27:25',
#   '2010-05-27 16:27:25',
#   None,
#   'GTSIMWQC')]
# (('creatorID', None, None, None, None, None, None),
#  ('creatorDataID', None, None, None, None, None, None),
#  ('dateAdded', None, None, None, None, None, None),
#  ('dateModified', None, None, None, None, None, None),
#  ('clientDateModified', None, None, None, None, None, None),
#  ('libraryID', None, None, None, None, None, None),
#  ('key', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM creators WHERE creatorID != creatorDataID LIMIT 3")
creators_exploring2 = cur.fetchall()
pprint.pprint(creators_exploring2)
cur.description
# Out:
# [(780,
#   302,
#   '2012-06-04 22:48:12',
#   '2012-06-04 22:48:12',
#   '2012-06-04 22:48:12',
#   None,
#   'JV639XMP'),
#  (781,
#   780,
#   '2012-06-04 22:48:12',
#   '2012-06-04 22:48:12',
#   '2012-06-04 22:48:12',
#   None,
#   'N89EUTBI'),
#  (782,
#   781,
#   '2012-06-04 22:49:30',
#   '2012-06-04 22:49:30',
#   '2012-06-04 22:49:30',
#   None,
#   'M6NAFPEX')]
# (('creatorID', None, None, None, None, None, None),
#  ('creatorDataID', None, None, None, None, None, None),
#  ('dateAdded', None, None, None, None, None, None),
#  ('dateModified', None, None, None, None, None, None),
#  ('clientDateModified', None, None, None, None, None, None),
#  ('libraryID', None, None, None, None, None, None),
#  ('key', None, None, None, None, None, None))

# %%
cur.execute("SELECT * FROM creatorData LIMIT 10")
creatorData_exploring = cur.fetchall()
pprint.pprint(creatorData_exploring)
cur.description
#Here are the author names.
# Out:
# [(1, 'Sung-June', 'Baek', '', 0, None),
#  (2, 'B.', 'Jagannadh', '', 0, None),
#  (3, 'Jagarlapudi A. R. P.', 'Sarma', '', 0, None),
#  (4, 'Aaron', 'Park', '', 0, None),
#  (5, 'Aiguo', 'Shen', '', 0, None),
#  (6, 'Kenzi', 'Hori', '', 0, None),
#  (7, 'Yoshihiko', 'Haruna', '', 0, None),
#  (8, 'Akio', 'Kamimura', '', 0, None),
#  (9, 'Hiroshi', 'Tsukube', '', 0, None),
#  (10, 'Takayuki.', 'Inoue', '', 0, None)]
# (('creatorDataID', None, None, None, None, None, None),
#  ('firstName', None, None, None, None, None, None),
#  ('lastName', None, None, None, None, None, None),
#  ('shortName', None, None, None, None, None, None),
#  ('fieldMode', None, None, None, None, None, None),
#  ('birthYear', None, None, None, None, None, None))

# %% [markdown]
# Author names are stored in the `creatorData` table with a `creatorDataID`, the list of creators is in the `creators` table with a `creatorID`. `creators` links to `creatorData`. The type of creator, e.g. author, is in the `creatorTypes` table with a `creatorTypeID`. The `itemCreators` table links the `itemID`, `creatorID`, and `creatorTypesID`.

# %%
#going to try to join in author info
cur.execute("SELECT * "
            "FROM itemCreators t1 "
            "LEFT JOIN creatorTypes t2 "
            "ON t1.creatorTypeID = t2.creatorTypeID "
            "LEFT JOIN creators t3 "
            "ON t1.creatorID = t3.creatorID "
            "LEFT JOIN creatorData t4 "
            "ON t3.creatorDataID = t4.creatorDataID "
            "WHERE t1.itemID BETWEEN 100 AND 110 "
           )
item_and_authors_test = cur.fetchall()
pprint.pprint(item_and_authors_test)
cur.description
# Out:
# [(102,
#   85,
#   1,
#   0,
#   1,
#   'author',
#   85,
#   85,
#   '2010-06-01 17:09:59',
#   '2010-06-01 17:09:59',
#   '2010-06-01 17:09:59',
#   None,
#   'AWEACHRQ',
#   85,
#   'Christopher J.',
#   'Rowlands',
#   '',
#   0,
#   None),
#  (102,
#   86,
#   1,
#   1,
#   1,
#   'author',
#   86,
#   86,
#   '2010-06-01 17:09:59',
#   '2010-06-01 17:09:59',
#   '2010-06-01 17:09:59',
#   None,
#   'BZKJAH72',
#   86,
#   'Stephen R.',
#   'Elliott',
#   '',
#   0,
#   None),
#  (105,
#   87,
#   1,
#   0,
#   1,
#   'author',
#   87,
#   87,
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   None,
#   '87PCQQ52',
#   87,
#   'Jared',
#   'Clark',
#   '',
#   0,
#   None),
#  (105,
#   88,
#   1,
#   1,
#   1,
#   'author',
#   88,
#   88,
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   None,
#   'F55SAJVI',
#   88,
#   'Seth T.',
#   'Call',
#   '',
#   0,
#   None),
#  (105,
#   89,
#   1,
#   2,
#   1,
#   'author',
#   89,
#   89,
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   None,
#   '7W6SSQ2N',
#   89,
#   'Daniel E.',
#   'Austin',
#   '',
#   0,
#   None),
#  (105,
#   90,
#   1,
#   3,
#   1,
#   'author',
#   90,
#   90,
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   '2010-06-01 17:24:56',
#   None,
#   '6A4FT7BJ',
#   90,
#   'Jaron C.',
#   'Hansen',
#   '',
#   0,
#   None),
#  (109,
#   91,
#   1,
#   0,
#   1,
#   'author',
#   91,
#   91,
#   '2010-06-01 17:28:01',
#   '2010-06-01 17:28:01',
#   '2010-06-01 17:28:01',
#   None,
#   'QET5HZK3',
#   91,
#   'Wei',
#   'Li',
#   '',
#   0,
#   None),
#  (109,
#   92,
#   1,
#   1,
#   1,
#   'author',
#   92,
#   92,
#   '2010-06-01 17:28:01',
#   '2010-06-01 17:28:01',
#   '2010-06-01 17:28:01',
#   None,
#   'GIR4SKBU',
#   92,
#   'Piotr',
#   'Piecuch',
#   '',
#   0,
#   None)]
# (('itemID', None, None, None, None, None, None),
#  ('creatorID', None, None, None, None, None, None),
#  ('creatorTypeID', None, None, None, None, None, None),
#  ('orderIndex', None, None, None, None, None, None),
#  ('creatorTypeID', None, None, None, None, None, None),
#  ('creatorType', None, None, None, None, None, None),
#  ('creatorID', None, None, None, None, None, None),
#  ('creatorDataID', None, None, None, None, None, None),
#  ('dateAdded', None, None, None, None, None, None),
#  ('dateModified', None, None, None, None, None, None),
#  ('clientDateModified', None, None, None, None, None, None),
#  ('libraryID', None, None, None, None, None, None),
#  ('key', None, None, None, None, None, None),
#  ('creatorDataID', None, None, None, None, None, None),
#  ('firstName', None, None, None, None, None, None),
#  ('lastName', None, None, None, None, None, None),
#  ('shortName', None, None, None, None, None, None),
#  ('fieldMode', None, None, None, None, None, None),
#  ('birthYear', None, None, None, None, None, None))

# %%
#Looking at how many creator types I have
cur.execute("SELECT DISTINCT creatorType "
            "FROM itemCreators t1 "
            "LEFT JOIN creatorTypes t2 "
            "ON t1.creatorTypeID = t2.creatorTypeID "
            "LEFT JOIN creators t3 "
            "ON t1.creatorID = t3.creatorID "
            "LEFT JOIN creatorData t4 "
            "ON t3.creatorDataID = t4.creatorDataID "
           )
item_and_authors_test2 = cur.fetchall()
pprint.pprint(item_and_authors_test2)
# Out:
# [('author',), ('contributor',), ('editor',), ('programmer',)]

# %% [markdown]
# ### Insights
# I have a way to examine all the data now. I would like to look at the authors and journals to see if there are some that I should be following that I currently am not.

# %%
#look at journals
cur.execute("SELECT t3.value, COUNT(t3.value) "
            "FROM itemData t1 "
            "LEFT JOIN fields t2 "
            "ON t1.fieldID = t2.fieldID "
            "LEFT JOIN itemDataValues t3 "
            "ON t1.valueID = t3.valueID "
            "WHERE t2.fieldName = 'publicationTitle' "
            "GROUP BY t3.value "
            "HAVING COUNT(t3.value) > 10 "
            "ORDER BY COUNT(t3.value) DESC"
           )
journal_count = cur.fetchall()
pprint.pprint(journal_count)
cur.description
# Out:
# [('The Journal of Physical Chemistry B', 179),
#  ('Langmuir', 63),
#  ('The Journal of Chemical Physics', 63),
#  ('The Journal of Physical Chemistry A', 58),
#  ('Journal of the American Chemical Society', 57),
#  ('Proceedings of the National Academy of Sciences', 41),
#  ('Physical Chemistry Chemical Physics', 38),
#  ('The Journal of Physical Chemistry Letters', 35),
#  ('Phys. Chem. Chem. Phys.', 33),
#  ('The Journal of Physical Chemistry C', 31),
#  ('Chemical Physics Letters', 30),
#  ('Physical Review B', 29),
#  ('Physical Review Letters', 29),
#  ('Annual Review of Physical Chemistry', 21),
#  ('J. Phys. Chem. B', 18),
#  ('Science', 18),
#  ('Physical Review E', 16),
#  ('Journal of Chemical Theory and Computation', 15),
#  ('Faraday Discussions', 13),
#  ('Journal of Raman Spectroscopy', 13),
#  ('Accounts of Chemical Research', 12),
#  ('Applied Spectroscopy', 12),
#  ('Nano Letters', 12),
#  ('Journal of Molecular Liquids', 11)]
# (('value', None, None, None, None, None, None),
#  ('COUNT(t3.value)', None, None, None, None, None, None))

# %% [markdown]
# Some of these entries have abbreviations instead of the full journal title. I will have to change that.

# %% [markdown]
# Most of these are already in my RSS feed, which is likely why they have high counts. I did notice that my feed for "Physical Chemistry Chemical Physics" was not generating anything, so I updated the feed URL. I was not following Journal of Physical Chemistry C, Chemical Physics Letters, Journal of Chemical Theory and Computation, Nano Letters, or Journal of Molecular Liquids. I have added those to my feed now.

# %%
#testing name concatenation
cur.execute("SELECT firstName, lastName, lastName || ', ' || firstName AS name FROM creatorData LIMIT 10")
creatorData_exploring = cur.fetchall()
pprint.pprint(creatorData_exploring)
cur.description
# Out:
# [('Peter', 'Abbamonte', 'Abbamonte, Peter'),
#  ('Nicholas L.', 'Abbott', 'Abbott, Nicholas L.'),
#  ('Kiharu', 'Abe', 'Abe, Kiharu'),
#  ('Bernd', 'Abel', 'Abel, Bernd'),
#  ('Rosary C. T.', 'Abot', 'Abot, Rosary C. T.'),
#  ('A. A.', 'Absanov', 'Absanov, A. A.'),
#  ('A.A.', 'Absanov', 'Absanov, A.A.'),
#  ('Bumaliya', 'Abulimiti', 'Abulimiti, Bumaliya'),
#  ('Nancy', 'Acelas', 'Acelas, Nancy'),
#  ('Claribel', 'Acevedo-Vélez', 'Acevedo-Vélez, Claribel')]
# (('firstName', None, None, None, None, None, None),
#  ('lastName', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None))

# %%
cur.execute("SELECT lastName || ', ' || firstName AS name, "
            "COUNT(lastName || ', ' || firstName) AS count "
            "FROM creatorData "
            "GROUP BY name "
            #"HAVING count > 2 "
            "ORDER BY count DESC"
           )
journal_count = cur.fetchall()
pprint.pprint(journal_count)
cur.description
#These are the distinct names!! Not how many times they're used. I also have duplicate spellings.
#I'll have to look into that.
# Out:
# [('Abbamonte, Peter', 1),
#  ('Abbott, Nicholas L.', 1),
#  ('Abe, Kiharu', 1),
#  ('Abel, Bernd', 1),
#  ('Abot, Rosary C. T.', 1),
#  ('Absanov, A. A.', 1),
#  ('Absanov, A.A.', 1),
#  ('Abulimiti, Bumaliya', 1),
#  ('Acelas, Nancy', 1),
#  ('Acevedo-Vélez, Claribel', 1),
#  ('Acharya, Hari', 1),
#  ('Achete, C. A.', 1),
#  ('Achtyl, Jennifer L.', 1),
#  ('Ackerman, M. L.', 1),
#  ('Acremann, Yves', 1),
#  ('Adachi, Shunsuke', 1),
#  ('Adam, Patrick', 1),
#  ('Adam, S.', 1),
#  ('Adams, Ellen M.', 1),
#  ('Adamson, Arthur W.', 1),
#  ('Adhikari, Narayan Prasad', 1),
#  ('Aeppli, Gabriel', 1),
#  ('Agren, Hans', 1),
#  ('Aguiar, Hilton B. de', 1),
#  ('Aguilar, Manuel A.', 1),
#  ('Ahmed, M. Shamsuddin', 1),
#  ('Ahmed, Mohammed', 1),
#  ('Ahmed, Saima', 1),
#  ('Ajayan, Pulickel M.', 1),
#  ('Akhtar, Shamim', 1),
#  ('Al-Abadleh, Hind A.', 1),
#  ('Al-Nossiff, Amani A.', 1),
#  ('Albertorio, Fernando', 1),
#  ('Alegria, Angel', 1),
#  ('Algaba, J.', 1),
#  ('Alivisatos, A. Paul', 1),
#  ('Alizadeh Pahlavan, Amir', 1),
#  ('Allen, Daniel B.', 1),
#  ('Allen, Heather C.', 1),
#  ('Alqus, Rasha', 1),
#  ('Als-Nielsen, J.', 1),
#  ('Alsenoy, Christian van', 1),
#  ('Aluru, Narayana R.', 1),
#  ('Alzate-Morales, Jans H.', 1),
#  ('Amarasiriwardena, Dula', 1),
#  ('American Mathematical Society, ', 1),
#  ('An, Jinho', 1),
#  ('Andelman, David', 1),
#  ('Anderko, Andrzej', 1),
#  ('Anderson, Nathaniel A.', 1),
#  ('Anderson, Travers H.', 1),
#  ('Anderson, Travis', 1),
#  ('Andersson, Martin Peter', 1),
#  ('Ando, Koji', 1),
#  ('Andonian, M. R.', 1),
#  ('Andrews, David L.', 1),
#  ('Andric, Jelena M.', 1),
#  ('Ang, Ha M.', 1),
#  ('Ang, Priscilla K.', 1),
#  ('Ang, Priscilla Kailian', 1),
#  ('Angelina, Emilio L.', 1),
#  ('Anglada, J. M.', 1),
#  ('Anglada, Josep M.', 1),
#  ('Angus-Smyth, Anna', 1),
#  ('Anisimov, S. I.', 1),
#  ('Annapureddy, Harsha V. R.', 1),
#  ('Ansar, Siyam M.', 1),
#  ('Antoine, R.', 1),
#  ('Ao, Mingqi', 1),
#  ('Ao, Z. M.', 1),
#  ('Apalkov, Vadym', 1),
#  ('Applegate, Brian E.', 1),
#  ('Arakawa, Seiji', 1),
#  ('Araki, Masatake', 1),
#  ('Araoka, F.', 1),
#  ('Aratono, M.', 1),
#  ('Aratono, Makoto', 1),
#  ('Ariese, Freek', 1),
#  ('Arima, Kenta', 1),
#  ('Armentrout, P. B.', 1),
#  ('Armstrong, Jeff', 1),
#  ('Arora, Pooja', 1),
#  ('Artyukhov, Vasilii I.', 1),
#  ('Arvaniti, Eirini', 1),
#  ('Arzhantsev, Sergey', 1),
#  ('Asada, Masahiro', 1),
#  ('Asadabadi, Simin', 1),
#  ('Asakuma, Yusuke', 1),
#  ('Asgari, Reza', 1),
#  ('Ash, Benjamin J.', 1),
#  ('Ashbaugh, Henry S.', 1),
#  ('Ashraf, Ali', 1),
#  ('Austin, Daniel E.', 1),
#  ('Aveyard, R.', 1),
#  ('Aveyard, Robert', 1),
#  ('Avnir, David', 1),
#  ('Azam, Md. Shafiul', 1),
#  ('Aziz, Emad F.', 1),
#  ('BEN-AMOTZ, DOR', 1),
#  ('BENEVIDES, James M.', 1),
#  ('Ba, De-Xin', 1),
#  ('Babiaczyk, Wojtek Iwo', 1),
#  ('Bachelier, Guillaume', 1),
#  ('Bachmann, Stephan J.', 1),
#  ('Backus, Ellen', 1),
#  ('Backus, Ellen H. G.', 1),
#  ('Baek, Sung-June', 1),
#  ('Baer, Marcel D.', 1),
#  ('Bahramian, Alireza', 1),
#  ('Bain, C.', 1),
#  ('Bain, C. D.', 1),
#  ('Bain, C.D.', 1),
#  ('Bain, Colin D.', 1),
#  ('Baisley, Tammy L.', 1),
#  ('Bajaj, Pushp', 1),
#  ('Baker, Daniel R.', 1),
#  ('Bakker, H. J.', 1),
#  ('Bakker, Huib J.', 1),
#  ('Bakker, Huib. J.', 1),
#  ('Bakulin, Artem A.', 1),
#  ('Bakó, Imre', 1),
#  ('Balabin, Roman M.', 1),
#  ('Balasubramanian, Mahalingam', 1),
#  ('Baldelli, Steven', 1),
#  ('Baldwin, Robert L.', 1),
#  ('Ballauff, Matthias', 1),
#  ('Balzerowski, Patrick', 1),
#  ('Bandyopadhyay, Dibyendu', 1),
#  ('Bao, Jiming', 1),
#  ('Bao, Qiaoliang', 1),
#  ('Baonza, Valentín García', 1),
#  ('BarathManiKanth, Selvaraj', 1),
#  ('Barber, S. D.', 1),
#  ('Bargheer, M.', 1),
#  ('Barik, Sujit K.', 1),
#  ('Barnard, Rachel A.', 1),
#  ('Barnes, A. C.', 1),
#  ('Barraza-Lopez, Salvador', 1),
#  ('Barrett, A. S.', 1),
#  ('Barty, A.', 1),
#  ('Barua, Sutapa', 1),
#  ('Bauer, S.', 1),
#  ('Baul, Upayan', 1),
#  ('Beaglehole, D.', 1),
#  ('Beaman, Daniel K.', 1),
#  ('Beattie, James K', 1),
#  ('Beattie, James K.', 1),
#  ('Beaudoin, Eric N.', 1),
#  ('Bechtel, Hans', 1),
#  ('Beck, Bernd', 1),
#  ('Beck, M.', 1),
#  ('Becker, Matthew L.', 1),
#  ('Beer, Alex G. F. de', 1),
#  ('Begum, Roksana', 1),
#  ('Behrens, Sven Holger', 1),
#  ('Bekyarova, Elena', 1),
#  ('Belkin, M. A.', 1),
#  ('Bell, Graham R.', 1),
#  ('Bell, Steven E. J.', 1),
#  ('Bellaiche, L.', 1),
#  ('Belyaeva, Elena A.', 1),
#  ('Ben Ishai, Paul', 1),
#  ('Ben-Amotz, Dor', 1),
#  ('Ben-Amotz, Dor.', 1),
#  ('Bencivenga, Filippo', 1),
#  ('Bender, John. S.', 1),
#  ('Benderskii, Alexander V.', 1),
#  ('Benichou, Emmanuel', 1),
#  ('Benjamin, Ilan', 1),
#  ('Benken, Rainer', 1),
#  ('Benkert, A.', 1),
#  ('Benkert, Andreas', 1),
#  ('Bennett, Kochise', 1),
#  ('Bera, B.', 1),
#  ('Berendsen, H. J. C.', 1),
#  ('Berendsen, Herman J. C.', 1),
#  ('Berge, B.', 1),
#  ('Bergonzi, Isabelle', 1),
#  ('Berhanu, Michael', 1),
#  ('Berkowitz, Max L.', 1),
#  ('Bermúdez-Salguero, Carolina', 1),
#  ('Bernal, Pedro', 1),
#  ('Berne, B. J.', 1),
#  ('Berntsen, P.', 1),
#  ('Berná, Antonio', 1),
#  ('Bertin, Paul A.', 1),
#  ('Bertrand, Emanuel', 1),
#  ('Besemer, Matthieu', 1),
#  ('Besson, Françoise', 1),
#  ('Bettega, M. H. F.', 1),
#  ('Beunen, J.A.', 1),
#  ('Bevington, Philip R.', 1),
#  ('Beye, M.', 1),
#  ('Beyer, Sebastian R.', 1),
#  ('Bezares, Francisco J.', 1),
#  ('Bharathi, M. S.', 1),
#  ('Bhattacharyya, Indrani', 1),
#  ('Bhattacharyya, Kankan', 1),
#  ('Bialkowski, J.', 1),
#  ('Bian, Hong-tao', 1),
#  ('Bian, Hongtao', 1),
#  ('Bier, Markus', 1),
#  ('Bieze, T.W.N.', 1),
#  ('Biggin, Philip', 1),
#  ('Binks, B. P.', 1),
#  ('Birner, Stefan', 1),
#  ('Biscay, Frédéric', 1),
#  ('Biswas, Parbati', 1),
#  ('Bixby, R. E.', 1),
#  ('Bjorneholm, Olle', 1),
#  ('Blake, P.', 1),
#  ('Blanco, Mario', 1),
#  ('Blandamer, Michael J.', 1),
#  ('Blankschtein, Daniel', 1),
#  ('Blas, F. J.', 1),
#  ('Bloemenkamp, Rob', 1),
#  ('Bloomfield, Aaron', 1),
#  ('Blower, Patrick G.', 1),
#  ('Bluhm, H.', 1),
#  ('Bluhm, Hendrik', 1),
#  ('Blum, M.', 1),
#  ('Blum, Monika', 1),
#  ('Boche, Gernot.', 1),
#  ('Boda, Dezső', 1),
#  ('Bogan, M. J.', 1),
#  ('Boinovich, Ludmila', 1),
#  ('Bojahr, A.', 1),
#  ('Bolhuis, Peter G.', 1),
#  ('Bonales, Laura Jiménez', 1),
#  ('Bonella, Sara', 1),
#  ('Boneva, Mariana P.', 1),
#  ('Bonn, D.', 1),
#  ('Bonn, Daniel', 1),
#  ('Bonn, M.', 1),
#  ('Bonn, Mischa', 1),
#  ('Bonoli, L.', 1),
#  ('Bonthuis, Douwe Jan', 1),
#  ('Booth, T. J.', 1),
#  ('Bopp, Ph. A.', 1),
#  ('Bora, Tanujjal', 1),
#  ('Borca-Tasciuc, Theodorian', 1),
#  ('Bordag, M.', 1),
#  ('Bordenyuk, Andrey N.', 1),
#  ('Boreyko, Jonathan B.', 1),
#  ('Borgis, Daniel', 1),
#  ('Borguet, E.', 1),
#  ('Borguet, Eric', 1),
#  ('Borkovec, Michal', 1),
#  ('Bose, Arijit', 1),
#  ('Bose, K S', 1),
#  ('Boström, M.', 1),
#  ('Boström, Mathias', 1),
#  ('Bothschafter, Elisabeth M.', 1),
#  ('Bottesch, R.', 1),
#  ('Boudouris, Bryan W.', 1),
#  ('Bourdon, Chris J.', 1),
#  ('Bourson, Patrice', 1),
#  ('Bouř, Petr', 1),
#  ('Boutet, S.', 1),
#  ('Bouzida, Djamal', 1),
#  ('Bowers, James', 1),
#  ('Bowler, David R.', 1),
#  ('Bowman, Joel M.', 1),
#  ('Bowron, D. T.', 1),
#  ('Boyd, Russell J.', 1),
#  ('Boyd, Susan L.', 1),
#  ('Boyer, Robert D.', 1),
#  ('Boyes, Adrian P.', 1),
#  ('Bozek, J. D.', 1),
#  ('Bradforth, Stephen E.', 1),
#  ('Brandt, K G', 1),
#  ('Brar, Victor W.', 1),
#  ('Braslau, A.', 1),
#  ('Bratz, A.', 1),
#  ('Braun, Rudiger', 1),
#  ('Bravo, A. I. Moreno-Ventas', 1),
#  ('Breen, Jan', 1),
#  ('Breher, Frank', 1),
#  ('Breindl, Andreas', 1),
#  ('Bresme, Fernando', 1),
#  ('Brevet, P. F.', 1),
#  ('Brevet, Pierre F.', 1),
#  ('Brevet, Pierre-François', 1),
#  ('Brezesinski, Gerald', 1),
#  ('Bridelli, Maria Grazia', 1),
#  ('Briggner, Lars-Erik', 1),
#  ('Brinzer, Thomas', 1),
#  ('Britt, David W.', 1),
#  ('Brochard-Wyart, Françoise', 1),
#  ('Brodeur, A.', 1),
#  ('Broido, D. A.', 1),
#  ('Brooks, Carlton F.', 1),
#  ('Brooks, Charles L.', 1),
#  ('Brorsen, Kurt R.', 1),
#  ('Broseta, D.', 1),
#  ('Broseta, Daniel', 1),
#  ('Browder, Breanna', 1),
#  ('Brown, Eric C.', 1),
#  ('Brown, Lola', 1),
#  ('Brown, M. G.', 1),
#  ('Brown, Mac G.', 1),
#  ('Brown, Matthew A.', 1),
#  ('Brown, Philip J.', 1),
#  ('Broyer, M.', 1),
#  ('Brubach, Jean-Blaise', 1),
#  ('Bruce, Chrystal D.', 1),
#  ('Bruce, Ian C.', 1),
#  ('Bryan, Richard L.', 1),
#  ('Bryce, Richard A.', 1),
#  ('Bryl, Krzysztof', 1),
#  ('Bu, Wei', 1),
#  ('Buch, V.', 1),
#  ('Buch, Victoria', 1),
#  ('Buchbinder, Avram M.', 1),
#  ('Bucher, Denis', 1),
#  ('Buchner, Franziska', 1),
#  ('Buckingham, A. D.', 1),
#  ('Buda, M', 1),
#  ('Buehler, Markus J.', 1),
#  ('Buff, Frank P.', 1),
#  ('Bui, Phuc T.', 1),
#  ('Bulo, Rosa E.', 1),
#  ('Bunn, Albert', 1),
#  ('Burai, Tarak N.', 1),
#  ('Burnham, Christian J.', 1),
#  ('Busch, Sebastian', 1),
#  ('Buschmann, Hans Juergen.', 1),
#  ('Buschmann, Hans-Jürgen', 1),
#  ('Bush, Matthew F.', 1),
#  ('Bushuev, V. A.', 1),
#  ('Butet, Jérémy', 1),
#  ('Butorac, Vjekoslav', 1),
#  ('Byers, J. D.', 1),
#  ('Byers, Jeffrey D.', 1),
#  ('Byrnes, Steven J.', 1),
#  ('Bär, M.', 1),
#  ('Bär, Marcus', 1),
#  ('Caballero, Julio', 1),
#  ('Cabello, Gema', 1),
#  ('Cabeza, Óscar', 1),
#  ('Cabral, Benedito J. Costa', 1),
#  ('Cadena-Nava, Ruben D.', 1),
#  ('Cai, Yu', 1),
#  ('Caldwell, Joshua D.', 1),
#  ('Call, Seth T.', 1),
#  ('Callahan, Karen M.', 1),
#  ('Callear, Samantha Kim', 1),
#  ('Camacho, Luis', 1),
#  ('Cameron, S.D.', 1),
#  ('Campana, Mario', 1),
#  ('Campbell, Charles T.', 1),
#  ('Campen, R. Kramer', 1),
#  ('Can, Süleyman Z.', 1),
#  ('Cancado, Luiz Gustavo', 1),
#  ('Cannizzo, Andrea', 1),
#  ('Canongia Lopes, José N.', 1),
#  ('Cantin, Sophie', 1),
#  ('Cançado, L. G.', 1),
#  ('Cao, Guozhong Z.', 1),
#  ('Cao, Peigen', 1),
#  ('Cao, Wei', 1),
#  ('Capaz, R. B.', 1),
#  ('Capp, Michael', 1),
#  ('Cappa, Christopher D.', 1),
#  ('Cappelletti, David', 1),
#  ('Car, Roberto', 1),
#  ('Carbone, F.', 1),
#  ('Carbone, Paola', 1),
#  ('Carignano, Marcelo A.', 1),
#  ('Carl, Damon R.', 1),
#  ('Caronna, C.', 1),
#  ('Carpenter, Andrew P.', 1),
#  ('Carpenter, William', 1),
#  ('Carrete, Jesús', 1),
#  ('Carrier, Odile', 1),
#  ('Carrington, Tucker', 1),
#  ('Casa, Diego', 1),
#  ('Casado-Chacón, Almudena', 1),
#  ('Casey, Jennifer R.', 1),
#  ('Casillas-Ituarte, Nadia N.', 1),
#  ('Casson, Brian D.', 1),
#  ('Castaño, Marcela', 1),
#  ('Castellana, Edward T.', 1),
#  ('Castleman, A. W.', 1),
#  ('Catalano, T.', 1),
#  ('Cattaneo, Stefano', 1),
#  ('Cavalleri, A.', 1),
#  ('Cavalli, A.', 1),
#  ('Cecchi, Teresa', 1),
#  ('Celebi, M.', 1),
#  ('Cerullo, Giulio', 1),
#  ('Cerveny, Silvina', 1),
#  ('Chaban, Vitaly V.', 1),
#  ('Chacón, Enrique', 1),
#  ('Chaikin, Paul M.', 1),
#  ('Chaiko, David', 1),
#  ('Chaimovich, Aviel', 1),
#  ('Chakarov, Dinko', 1),
#  ('Chakrabarti, M. H.', 1),
#  ('Chakrabarty, Suman', 1),
#  ('Chakraborty, Atanu', 1),
#  ('Chakravarty, Charusita', 1),
#  ('Chandler, David', 1),
#  ('Chandra, Amalendu', 1),
#  ('Chang, Kyeol', 1),
#  ('Chang, Terrence M.', 1),
#  ('Chang, Tsun-Mei', 1),
#  ('Chaplin, Martin', 1),
#  ('Chapman, Walter G.', 1),
#  ('Charvolin, J.', 1),
#  ('Chassot, Jean-Marie', 1),
#  ('Cheah, Kok Wai', 1),
#  ('Chen, C.', 1),
#  ('Chen, Chen', 1),
#  ('Chen, Chi-Fan', 1),
#  ('Chen, Guang-Jin', 1),
#  ('Chen, Hailong', 1),
#  ('Chen, Haixiang', 1),
#  ('Chen, Houyang', 1),
#  ('Chen, Hsing-Yin', 1),
#  ('Chen, Hua', 1),
#  ('Chen, Liao Y.', 1),
#  ('Chen, P.', 1),
#  ('Chen, Qian', 1),
#  ('Chen, Shumei', 1),
#  ('Chen, Shun-Li', 1),
#  ('Chen, Shunli', 1),
#  ('Chen, Wei', 1),
#  ('Chen, Xiangke', 1),
#  ('Chen, Xin', 1),
#  ('Chen, Xiyi', 1),
#  ('Chen, Xue-Jiao', 1),
#  ('Chen, Yixing', 1),
#  ('Chen, Zongping', 1),
#  ('Cheng, Hui-Ming', 1),
#  ('Cheng, J. L.', 1),
#  ('Cheng, Mark Ming-Cheng', 1),
#  ('Cheng, Ming Hsin', 1),
#  ('Cheng, Rongshi', 1),
#  ('Cheng, Wen-Hsi', 1),
#  ('Chervenak, Andrew', 1),
#  ('Chevigny, E.', 1),
#  ('Chialvo, Ariel', 1),
#  ('Chialvo, Ariel A.', 1),
#  ('Chiao, R. Y.', 1),
#  ('Chillemi, Giovanni', 1),
#  ('Chin, S. L.', 1),
#  ('Chipot, Christophe', 1),
#  ('Chiu, Chi-cheng', 1),
#  ('Cho, Minhaeng', 1),
#  ('Chodera, John D.', 1),
#  ('Choi, Cheol Ho', 1),
#  ('Choi, Sangkook', 1),
#  ('Choi, Tae Hoon', 1),
#  ('Chordia, Parag', 1),
#  ('Chorny, Ilya', 1),
#  ('Chou, Harry', 1),
#  ('Chou, Keng C.', 1),
#  ('Chou, Ming-Shean', 1),
#  ('Choudhury, Niharendu', 1),
#  ('Chowdhary, Janamejaya', 1),
#  ('Christofferson, Andrew J.', 1),
#  ('Christopoulos, Arthur', 1),
#  ('Chu, Fu-Sui', 1),
#  ('Chu, Y. C.', 1),
#  ('Chulkov, E. V.', 1),
#  ('Chun, Hayden', 1),
#  ('Chung, Chul', 1),
#  ('Chung, Hoeil', 1),
#  ('Chuntonov, Lev', 1),
#  ('Ciccotti, Giovanni', 1),
#  ('Cina, Jeffrey A.', 1),
#  ('Ciszewski, Regina K.', 1),
#  ('Claesson, Per M.', 1),
#  ('Clark, Aurora', 1),
#  ('Clark, Gary N. I.', 1),
#  ('Clark, Jared', 1),
#  ('Clark, Sue', 1),
#  ('Clark, Timothy', 1),
#  ('Claverie, Rémy', 1),
#  ('Clay, John R.', 1),
#  ('Clemens, Anna', 1),
#  ('Co, D. T.', 1),
#  ('Cobet, C.', 1),
#  ('Cogdell, Richard J.', 1),
#  ('Cohen, Asaf', 1),
#  ('Cohen, Ronald C.', 1),
#  ('Cohen-Karni, Tzahi', 1),
#  ('Cole, Daniel J.', 1),
#  ('Cole, Milton W.', 1),
#  ('Colherinhas, Guilherme', 1),
#  ('Collier, C. Patrick', 1),
#  ('Collins, Kim D.', 1),
#  ('Colmenero, Juan', 1),
#  ('Colombo, Chiara', 1),
#  ('Colombo, L.', 1),
#  ('Colombo, Luigi', 1),
#  ('Colosqui, Carlos E.', 1),
#  ('Colussi, Agustin J.', 1),
#  ('Colussi, Agustín J.', 1),
#  ('Comas-Garcia, Mauricio', 1),
#  ('Combet, J.', 1),
#  ('Comez, Lucia', 1),
#  ('Compagnini, Giuseppe', 1),
#  ('Conboy, J.', 1),
#  ('Conboy, J.C.', 1),
#  ('Conti, Claudia', 1),
#  ('Conway, B.E.', 1),
#  ('Coons, Marc P.', 1),
#  ('Cooper, Richard J.', 1),
#  ('Cooper, Theresa E.', 1),
#  ('Corbett, Karen M.', 1),
#  ('Corcelli, S. A.', 1),
#  ('Correa, Alfredo A.', 1),
#  ('Correia, Ricardo R. B.', 1),
#  ('Cortes, Juan', 1),
#  ('Courtois, H.', 1),
#  ('Coutinho, João A. P.', 1),
#  ('Coveney, Peter V.', 1),
#  ('Covert, Paul A.', 1),
#  ('Cox, Kenneth R.', 1),
#  ('Craig, John M.', 1),
#  ('Craig, Vincent S. J.', 1),
#  ('Cremer, Paul S', 1),
#  ('Cremer, Paul S.', 1),
#  ('Crichton, D.', 1),
#  ('Crippa, Pier Raimondo', 1),
#  ('Crommie, Michael', 1),
#  ('Crommie, Michael F.', 1),
#  ('Crowell, Robert A.', 1),
#  ('Croxton, Clive A.', 1),
#  ('Cruickshank, J. M.', 1),
#  ('Cueto-Felgueroso, Luis', 1),
#  ('Cugia, Francesca', 1),
#  ('Cui, Di', 1),
#  ('Cui, Guanglei', 1),
#  ('Cui, Qiang', 1),
#  ('Cui, Yu', 1),
#  ('Cummings, Oneka T.', 1),
#  ('Cummings, Peter', 1),
#  ('Cunha, Silvio L. S.', 1),
#  ('Currie, Marc', 1),
#  ('Cwikel, Dory', 1),
#  ('Cwiklik, Lukasz', 1),
#  ('Cáceres, Mercedes', 1),
#  ("D'Auria, Raffaella", 1),
#  ("D'Urso, Luisa", 1),
#  ('D. Steill, Jeffrey', 1),
#  ('Dadap, J. I.', 1),
#  ('Dadap, Jerry I.', 1),
#  ('Dadap, Jerry Icban', 1),
#  ('Dahint, R.', 1),
#  ('Dai, Hai-Lung', 1),
#  ('Dai, Liankui', 1),
#  ('Dai, Sheng', 1),
#  ('Dai, Yeling', 1),
#  ('Daikhin, L.I.', 1),
#  ('Dallinger, Gregory C.', 1),
#  ('Dalton, Casuarina N.', 1),
#  ('Dang, Liem X.', 1),
#  ('Dani, Archit', 1),
#  ('Dankerl, Markus', 1),
#  ('Danner, Sabine', 1),
#  ('Danos, L.', 1),
#  ('Danov, Krassimir D.', 1),
#  ('Dans, Pablo D.', 1),
#  ('Darré, Leonardo', 1),
#  ('Darré, Leonardo', 1),
#  ('Daschbach, J.', 1),
#  ('Daschbach, J.L.', 1),
#  ('Dastgheib, Seyed A.', 1),
#  ('Datskos, Panos G.', 1),
#  ('David, Jorge', 1),
#  ('Davidson, George', 1),
#  ('Davies, Paul B.', 1),
#  ('Davis, H.T.', 1),
#  ('Davis, Joel', 1),
#  ('Davis, Joel G.', 1),
#  ('Davoody, A. H.', 1),
#  ('De Marco, Luigi', 1),
#  ('De Silvestri, Sandro', 1),
#  ('DeFusco, Albert', 1),
#  ('DePonte, D. P.', 1),
#  ('DeVries, Arthur L.', 1),
#  ('Deamer, D.W.', 1),
#  ('Dean, Jesse J.', 1),
#  ('Debenedetti, P. G.', 1),
#  ('Debenedetti, Pablo G.', 1),
#  ('Deepak, Venkatraman', 1),
#  ('Defante, Adrian P.', 1),
#  ('Deguchi, Toshio', 1),
#  ('Dehen, Christopher J.', 1),
#  ('Deinert, Jan-Christoph', 1),
#  ('Delarue, Patrice', 1),
#  ('Delgado, José Manuel', 1),
#  ('Demeler, Borries', 1),
#  ('Dempsey, C. E.', 1),
#  ('Deng, Shihu H. M.', 1),
#  ('Deng, Xingyi', 1),
#  ('Dergacheva, L. V.', 1),
#  ('Deshmukh, Sanket A.', 1),
#  ('Deutsch, M.', 1),
#  ('Deutsch, Moshe', 1),
#  ('Devanathan, Ram', 1),
#  ('Devlin, J. Paul', 1),
#  ('Dey, Sandwip K.', 1),
#  ('Dhinojwala, Ali', 1),
#  ('Di Tommaso, Devis', 1),
#  ('Dian, Brian C.', 1),
#  ('Dibble, Collin J.', 1),
#  ('Dieckmann, Gregg R.', 1),
#  ('Diehl, Alexandre', 1),
#  ('Dieringer, Jon A.', 1),
#  ('Dietrich, S.', 1),
#  ('Dill, Ken A.', 1),
#  ('Dinda, Sirshendu', 1),
#  ('Ding, Jing', 1),
#  ('Ding, Y.', 1),
#  ('Ding, Yihong', 1),
#  ('Dishon, Matan', 1),
#  ('Djerdjev, Alex M.', 1),
#  ('Dobberschütz, Sören', 1),
#  ('Dobbs, Harvey', 1),
#  ('Dobson, P.', 1),
#  ('Doerr, A.', 1),
#  ('Dogliotti, L.', 1),
#  ('Doidge, Gregory P.', 1),
#  ('Domene, Carmen', 1),
#  ('Donadio, Davide', 1),
#  ('Dong, Hongxing', 1),
#  ('Dong, Shuo', 1),
#  ('Donley, Amber', 1),
#  ('Dori, Zvi', 1),
#  ('Dosch, Helmut', 1),
#  ('Dougal, S. M.', 1),
#  ('Dougherty, Dennis A.', 1),
#  ('Doughty, Benjamin', 1),
#  ('Dreesen, L.', 1),
#  ('Dresselhaus, G.', 1),
#  ('Dresselhaus, M.S.', 1),
#  ('Drever, JamesI', 1),
#  ('Drisdell, Walter S.', 1),
#  ('Du, Quan', 1),
#  ('Duffey, Kaitlin C.', 1),
#  ('Duffin, Andrew M.', 1),
#  ('Duflot, D.', 1),
#  ('Dufrêche, Jean-François', 1),
#  ('Duignan, Timothy T.', 1),
#  ('Dupuis, Michel', 1),
#  ('Durov, Vladimir A.', 1),
#  ('Durán-Meza, Ana L.', 1),
#  ('Dutta, Joydeep', 1),
#  ('Dutta, Samrat', 1),
#  ('Duvail, Magali', 1),
#  ('Dyson, Paul J.', 1),
#  ('Dünweg, Burkhard', 1),
#  ('D’Agostino, Carmine', 1),
#  ('D’Amico, Francesco', 1),
#  ('D’Angelo, Paola', 1),
#  ('D’Auria, Raffaella', 1),
#  ('Eastwood, James W.', 1),
#  ('Eaves, J. D.', 1),
#  ('Eaves, Joel D.', 1),
#  ('Echenique, P. M.', 1),
#  ("Ecole d'été de physique théorique (Les Houches, Haute-Savoie, France), ",
#   1),
#  ('Edalat, Faramarz', 1),
#  ('Edler, Karen J.', 1),
#  ('Eftekhari-Bafrooei, Ali', 1),
#  ('Eichhorn, Stephen J.', 1),
#  ('Eickhoff, Christian', 1),
#  ('Eisenthal, K. B.', 1),
#  ('Eisenthal, K.B.', 1),
#  ('Eisenthal, Kenneth B.', 1),
#  ('Elgabarty, Hossam', 1),
#  ('Elkins, M. H.', 1),
#  ('Elliott, Stephen', 1),
#  ('Elliott, Stephen R.', 1),
#  ('Emelyanenko, Alexandre', 1),
#  ('Emerson, John A.', 1),
#  ('Emmert, S.', 1),
#  ('Enami, Shinichi', 1),
#  ('Enders, S', 1),
#  ('Engberts, Jan B. F. N.', 1),
#  ('England, Alice H.', 1),
#  ('Eom, In-Yong', 1),
#  ('Ercius, Peter', 1),
#  ('Eriksson, Susanna K.', 1),
#  ('Ernst, K.-H.', 1),
#  ('Esenturk, Okan', 1),
#  ('Esser, N.', 1),
#  ('Evans, Geoff M', 1),
#  ('Evans, Geoffrey M.', 1),
#  ('Evans, Marjorie W.', 1),
#  ('Evans, R.', 1),
#  ('Everly, R. Michael', 1),
#  ('Ewing, George E.', 1),
#  ('FEGA, KATHRYN REBECCA', 1),
#  ('Fainerman, Valentin B.', 1),
#  ('Fainerman, Valentine B.', 1),
#  ('Faizullin, D. A.', 1),
#  ("Fal'ko, V. I.", 1),
#  ('Falcon, Eric', 1),
#  ('Fallah Fini, Mojtaba', 1),
#  ('Fallahazad, Babak', 1),
#  ('Fan, Fengtao', 1),
#  ('Fan, Gui-Chen', 1),
#  ('Fan, Heng', 1),
#  ('Fang, Haiping', 1),
#  ('Fang, Hui', 1),
#  ('Fang, Ying', 1),
#  ('Fang, Yuan', 1),
#  ('Farimani, Amir Barati', 1),
#  ('Fasolino, Annalisa', 1),
#  ('Faubel, Manfred', 1),
#  ('Fauster, Thomas', 1),
#  ('Fawcett, W', 1),
#  ('Fawcett, W. Ronald', 1),
#  ('Fawcett, W.Ronald', 1),
#  ('Fayer, Michael D.', 1),
#  ('Fdez. Galván, Ignacio', 1),
#  ('Fecko, C. J.', 1),
#  ('Fedoseeva, Marina', 1),
#  ('Fedotov, V. D.', 1),
#  ('Fega, K. R.', 1),
#  ('Fega, K. Rebecca', 1),
#  ('Fei, Zhaofu', 1),
#  ('Feig, Michael', 1),
#  ('Felderhof, B. U.', 1),
#  ('Felderhof, B.U.', 1),
#  ('Feldkamp, J.', 1),
#  ('Feldman, Yuri', 1),
#  ('Feliu, Juan Miguel', 1),
#  ('Feng, Dong-xia', 1),
#  ('Feng, Ran-ran', 1),
#  ('Feng, Xiaofeng', 1),
#  ('Feng, Zhaochi', 1),
#  ('Fennell, Christopher J.', 1),
#  ('Fenter, Paul', 1),
#  ('Fernandez, Ignacio', 1),
#  ('Fernandez, Julio M.', 1),
#  ('Fernández, Josefa', 1),
#  ('Ferrari, A. C.', 1),
#  ('Ferreira, E. H. Martins', 1),
#  ('Ferreira, Luisa A', 1),
#  ('Fiess, Markus', 1),
#  ('Figge, Florian', 1),
#  ('Fil, D. V.', 1),
#  ('Fileti, Eudes Eterno', 1),
#  ('Fine, D P', 1),
#  ('Finlayson-Pitts, Barbara J.', 1),
#  ('Finney, J. L.', 1),
#  ('Fioretto, Daniele', 1),
#  ('Fischer, Andreas', 1),
#  ('Fischer, Thomas M.', 1),
#  ('Fisher, L. R.', 1),
#  ('Fita, Piotr', 1),
#  ('Fleharty, Mark E.', 1),
#  ('Fletcher, P. D. I.', 1),
#  ('Fleurat-Lessard, Paul', 1),
#  ('Flores, Sarah C.', 1),
#  ('Fogarty, Aoife C.', 1),
#  ('Foist, Rod B.', 1),
#  ('Fomina, Elena S.', 1),
#  ('Fontana, Marc D.', 1),
#  ('Forte, Giuseppe', 1),
#  ('Fourkas, John T.', 1),
#  ('Fournier, Joseph A.', 1),
#  ('Fox, Malcolm F.', 1),
#  ('Fox, Malcom F.', 1),
#  ('Fradkin, Eduardo', 1),
#  ('Francisco, J. S.', 1),
#  ('Francisco, Joseph S.', 1),
#  ('Franck, John', 1),
#  ('Frank, Henry S.', 1),
#  ('Franz, Johannes', 1),
#  ('Fredj, Erick', 1),
#  ('Freites, J. Alfredo', 1),
#  ('Frey, J.G.', 1),
#  ('Freysz, Eric', 1),
#  ('Friedmann, Tamar', 1),
#  ('Frigato, Tomaso', 1),
#  ('Fritsch, Sebastian', 1),
#  ('Fu, Li', 1),
#  ('Fu, Qiang', 1),
#  ('Fuhrer, H.', 1),
#  ('Fujii, Asuka', 1),
#  ('Fujisawa, Kaori', 1),
#  ('Fukuhara, Koichi', 1),
#  ('Fukunaka, Yasuhiro', 1),
#  ('Fukuto, Masafumi', 1),
#  ('Fuller, Wayne A.', 1),
#  ('Fulton, John L.', 1),
#  ('Fulvio, Pasquale F.', 1),
#  ('Furlan, Alan', 1),
#  ('Furó, István', 1),
#  ('Fuster, Daniel', 1),
#  ('Föhlisch, Alexander', 1),
#  ('Gaal, P.', 1),
#  ('Gaburro, Zeno', 1),
#  ('Gaffney, Kelly J.', 1),
#  ('Gaigeot, Marie-Pierre', 1),
#  ('Gaire, Churamani', 1),
#  ('Galamba, N.', 1),
#  ('Galamba, Nuno', 1),
#  ('Galhenage, Randima P.', 1),
#  ('Gallego, Luis J.', 1),
#  ('Galletto, P.', 1),
#  ('Galli, Giulia', 1),
#  ('Gampe, Teresa', 1),
#  ('Gan, Wei', 1),
#  ('Gan, Yu', 1),
#  ('Ganesh, P.', 1),
#  ('Ganesh, Panchapakesan', 1),
#  ('Gang, O.', 1),
#  ('Ganguly, Pritam', 1),
#  ('Gao, Xiaodan', 1),
#  ('Gao, Yi Qin', 1),
#  ('Garcia-Araez, N.', 1),
#  ('Garcia-Araez, Nuria', 1),
#  ('García, Hermenegildo', 1),
#  ('Garde, S.', 1),
#  ('Garde, Shekhar', 1),
#  ('Garrett, Bruce C.', 1),
#  ('Garrett-Roe, Sean', 1),
#  ('Garrido, J. A.', 1),
#  ('Garrido, Jose A.', 1),
#  ('Gast, Alice P.', 1),
#  ('Gavish, Nir', 1),
#  ('Geetha, A.', 1),
#  ('Geiger, Alfons', 1),
#  ('Geiger, F.', 1),
#  ('Geiger, Franz', 1),
#  ('Geiger, Franz M.', 1),
#  ('Geim, A. K.', 1),
#  ('Geim, Andre K.', 1),
#  ('Geissler, P. L.', 1),
#  ('Geissler, Phillip L.', 1),
#  ('Gekle, Stephan', 1),
#  ('Gellert, P. R.', 1),
#  ('Gellman, Samuel H.', 1),
#  ('Gellner, Magdalena', 1),
#  ('Geng, Baisong', 1),
#  ('Gennes, Pierre-Gilles de', 1),
#  ('George, Subi J.', 1),
#  ('Georgiev, Georgi', 1),
#  ('Georgiev, Mircho', 1),
#  ('Germaine, Amy C.', 1),
#  ('Germash, K. V.', 1),
#  ('Geronimo, Inacrist', 1),
#  ('Gessini, Alessandro', 1),
#  ('Gewinner, Jürgen', 1),
#  ('Ghatak, Animangsu', 1),
#  ('Ghosal, S.', 1),
#  ('Ghosal, Sutapa', 1),
#  ('Ghosh, Manik K.', 1),
#  ('Ghosh, Manik Kumer', 1),
#  ('Ghosh, Swapan K.', 1),
#  ('Ghoufi, Aziz', 1),
#  ('Giammanco, Chiara H.', 1),
#  ('Gibb, Bruce C.', 1),
#  ('Gibbs-Davis, Julianne M.', 1),
#  ('Gierszal, Kamil P.', 1),
#  ('Giesecke, Marianne', 1),
#  ('Gilch, P.', 1),
#  ('Gilles, Mary K.', 1),
#  ('Giner-Casares, Juan J.', 1),
#  ('Giovambattista, N.', 1),
#  ('Girault, H. H.', 1),
#  ('Girault, Hubert H.', 1),
#  ('Girit, Caglar', 1),
#  ('Girotto, Matheus', 1),
#  ('Gladden, Lynn F.', 1),
#  ('Gladich, Ivan', 1),
#  ('Glen, Robert C.', 1),
#  ('Glover, William J.', 1),
#  ('Glumac, Nick', 1),
#  ('Gniazdowska, E.', 1),
#  ('Godawat, Rahul', 1),
#  ('Godbout, Nicolas', 1),
#  ('Goddard, William A.', 1),
#  ('Godec, Aljaž', 1),
#  ('Goebel, A.', 1),
#  ('Goel, Narendra S.', 1),
#  ('Gog, Thomas', 1),
#  ('Gogotsi, Yury', 1),
#  ('Gohlke, M.', 1),
#  ('Gojło, Emilia', 1),
#  ('Goken, Erin G.', 1),
#  ('Gomes, José R. B.', 1),
#  ('Gomes, M. F. Costa', 1),
#  ('Gomopoulos, Nikolaos', 1),
#  ('Gonella, Grazia', 1),
#  ('Gonzalez, Miguel Angel', 1),
#  ('Gonçalves da Silva, Amélia M. P. S.', 1),
#  ('Goodknight, J.', 1),
#  ('Gopalakrishnan, Sandhya', 1),
#  ('Gorby, Allen', 1),
#  ('Gordillo, M C', 1),
#  ('Gordon, Mark S.', 1),
#  ('Gorecka, E.', 1),
#  ('Gorrell, I. B.', 1),
#  ('Goswami, Debabrata', 1),
#  ('Goto, Tomohisa', 1),
#  ('Gottwald, A.', 1),
#  ('Goutev, Nicolai', 1),
#  ('Goutev, Nikolay', 1),
#  ('Gracia-Fadrique, Jesús', 1),
#  ('Grass, S.', 1),
#  ('Gray, Harry B.', 1),
#  ('Gray-Weale, Angus', 1),
#  ('Gray-Weale, Angus Anthony', 1),
#  ('Grees, B.', 1),
#  ('Grest, Gary S.', 1),
#  ('Grier, David G.', 1),
#  ('Griffith, Elizabeth C.', 1),
#  ('Grigera, J. R.', 1),
#  ('Grigorenko, A. N.', 1),
#  ('Grigorieva, Irina V.', 1),
#  ('Grillet, Anne M.', 1),
#  ('Grimes, Brian A.', 1),
#  ('Grishina, N.', 1),
#  ('Gronbeck, Henrik', 1),
#  ('Grondin, Joseph', 1),
#  ('Grosberg, A. Yu.', 1),
#  ('Grossfield, Alan', 1),
#  ('Grozev, Nikolay A.', 1),
#  ('Grunze, M.', 1),
#  ('Grübel, G.', 1),
#  ('Guardia, E.', 1),
#  ('Guerra, Rodrigo E.', 1),
#  ('Guerrero García, Guillermo Iván', 1),
#  ('Guerrero-García, Guillermo Iván', 1),
#  ('Guest, W. L.', 1),
#  ('Gugel, Dieter', 1),
#  ('Guidoni, Leonardo', 1),
#  ('Guinea, F.', 1),
#  ('Guinn, Emily', 1),
#  ('Gulapalli, Hemtej', 1),
#  ('Gulich, R.', 1),
#  ('Gullapalli, Hemtej', 1),
#  ('Guo, Dan', 1),
#  ('Guo, J.', 1),
#  ('Guo, Meiling', 1),
#  ('Guo, Tian-Min', 1),
#  ('Guo, Yuan', 1),
#  ('Gurau, Marc C.', 1),
#  ('Gurunathan, Sangiliyandi', 1),
#  ('Gustafson, T. K.', 1),
#  ('Gutberlet, Thomas', 1),
#  ('Guven, O.', 1),
#  ('Gvozdic, Vlatka', 1),
#  ('Götz, Andreas W.', 1),
#  ('Habartová, Alena', 1),
#  ('Haber, Louis H.', 1),
#  ('Haddon, Robert C.', 1),
#  ('Hagan, Michael F.', 1),
#  ('Hagen, C. R.', 1),
#  ('Hagen, Sebastian', 1),
#  ('Hagfeldt, Anders', 1),
#  ('Hajimolana, S. A.', 1),
#  ('Hakala, Mikko', 1),
#  ('Hale, George M.', 1),
#  ('Halicioglu, T.', 1),
#  ('Hall, Benjamin A.', 1),
#  ('Hall, R.B.', 1),
#  ('Hall, Shaun A.', 1),
#  ('Hallberg, Fredrik', 1),
#  ('Hallinan, Daniel T.', 1),
#  ('Hamad, Said', 1),
#  ('Hamaker, H.C.', 1),
#  ('Hamann, Thomas W.', 1),
#  ('Hamashima, Toru', 1),
#  ('Hamm, Peter', 1),
#  ('Hammer, Malte U.', 1),
#  ('Hammer, Nathan I.', 1),
#  ('Hampton, C. Y.', 1),
#  ('Hampton, Marc A.', 1),
#  ('Han, Songi', 1),
#  ('Han, Suzee', 1),
#  ('Hancock, Robert D.', 1),
#  ('Hande, Vrushali R.', 1),
#  ('Hands, Michael D.', 1),
#  ('Hanna, Jeanette D.', 1),
#  ('Hanna, S.', 1),
#  ('Hannongbua, Supot', 1),
#  ('Hansen Galen J., ', 1),
#  ('Hansen Wilford N., ', 1),
#  ('Hansen, Jaron C.', 1),
#  ('Hansen, Wilford N.', 1),
#  ('Hao, Yufeng', 1),
#  ('Hao, Zhao', 1),
#  ('Haque, Imran S.', 1),
#  ('Hargreaves, L. R.', 1),
#  ('Harish T, Shilpa', 1),
#  ('Harnau, Ludger', 1),
#  ('Harrington, RebeccaR', 1),
#  ('Harris, R. C.', 1),
#  ('Harris, Robert A.', 1),
#  ('Harris, Stephen J.', 1),
#  ('Hars�nyi, I.', 1),
#  ('Harth, Kirsten', 1),
#  ('Hartsock, Robert', 1),
#  ('Haruna, Yoshihiko', 1),
#  ('Hasegawa, Taisuke', 1),
#  ('Hasegawaa, Taisuke', 1),
#  ('Hasi, Wu-Li-Ji', 1),
#  ('Hassanali, A. A.', 1),
#  ('Hassanali, Ali A.', 1),
#  ('Hassenkam, Tue', 1),
#  ('Hata, Toshiyuki', 1),
#  ('Hatlo, Marius M.', 1),
#  ('Hauf, M. V.', 1),
#  ('Hauf, Moritz V.', 1),
#  ('Hauxwell, F.', 1),
#  ('Havener, Robin W.', 1),
#  ('Hayami, Yoshiteru', 1),
#  ('Hayashi, K.', 1),
#  ('Hayashi, Nobuhiko', 1),
#  ('Hayashi, T.', 1),
#  ('Haydon, D. A.', 1),
#  ('Hayon, E.', 1),
#  ('Hayon, Elie', 1),
#  ('He, Jianying', 1),
#  ('He, Kevin T.', 1),
#  ('He, Ping', 1),
#  ('He, Yi', 1),
#  ('Head-Gordon, T.', 1),
#  ('Head-Gordon, Teresa', 1),
#  ('Healy, T. W.', 1),
#  ('Heath, James R.', 1),
#  ('Hebensteit, Eleonore L. D.', 1),
#  ('Hebert, Philippe', 1),
#  ('Hector, Louis G.', 1),
#  ('Hedderich, Hartmut G.', 1),
#  ('Heffern, Charles T. R.', 1),
#  ('Hefter, Glenn', 1),
#  ('Heine, David R.', 1),
#  ('Heinz, Tony F.', 1),
#  ('Heiranian, Mohammad', 1),
#  ('Heisler, I. A.', 1),
#  ('Heisler, Ismael A.', 1),
#  ('Hel-Or, Hagit Zabrodsky', 1),
#  ('Hellberg, Lars', 1),
#  ('Hellebusch, Daniel J.', 1),
#  ('Hemminger, John C.', 1),
#  ('Henchman, Richard H.', 1),
#  ('Henderson, Douglas', 1),
#  ('Henderson, J. Michael', 1),
#  ('Henderson, Michael A.', 1),
#  ('Henry, Christine L.', 1),
#  ('Herbert, John M.', 1),
#  ('Hermansson, Kersti', 1),
#  ('Hermelink, Antje', 1),
#  ('Herrera, Fernando E.', 1),
#  ('Hersam, Mark C.', 1),
#  ('Hertel, I. V.', 1),
#  ('Herz, Alexander', 1),
#  ('Herzon, Seth B.', 1),
#  ('Heselden, Roy', 1),
#  ('Heske, C.', 1),
#  ('Heske, Clemens', 1),
#  ('Hess, Berk', 1),
#  ('Hess, L. H.', 1),
#  ('Hess, Lucas H.', 1),
#  ('Hey, John C.', 1),
#  ('Hey, Michael J.', 1),
#  ('Heyda, Jan', 1),
#  ('Hicks, J. M.', 1),
#  ('Hicks, Janice M.', 1),
#  ('Hill, Elisabeth K.', 1),
#  ('Hillyer, Matthew B.', 1),
#  ('Hilty, Christian', 1),
#  ('Hincapié, Gina', 1),
#  ('Hiranuma, Yojiro', 1),
#  ('Hirst, Christopher', 1),
#  ('Ho, Davy', 1),
#  ('Ho, Tuan A.', 1),
#  ('Hoang, Bryan T.', 1),
#  ('Hochstrasser, Robin M.', 1),
#  ('Hockney, Roger W.', 1),
#  ('Hodeck, Kai F.', 1),
#  ('Hodzic, Aden', 1),
#  ('Hoffmann, Martin', 1),
#  ('Hoffmann, Michael R.', 1),
#  ('Hoffmann, S. V.', 1),
#  ('Hofstetter, Michael', 1),
#  ('Hogan, Patrick A.', 1),
#  ('Hokmabadi, M. S.', 1),
#  ('Holden, Carol A.', 1),
#  ('Hollars, Christopher W.', 1),
#  ('Hollingsworth, Andrew D.', 1),
#  ('Holte, Lars K.', 1),
#  ('Holzner, Simon', 1),
#  ('Hone, James', 1),
#  ('Hong, Byung Hee', 1),
#  ('Hong, Seok-Cheol', 1),
#  ('Honma, Itaru', 1),
#  ('Hopkins, Adam J.', 1),
#  ('Hore, Dennis K.', 1),
#  ('Hori, Kenzi', 1),
#  ('Horinek, Dominik', 1),
#  ('Horio, Takuya', 1),
#  ('Horng, Jason', 1),
#  ('Hortal, Ana R.', 1),
#  ('Hosono, Eiji', 1),
#  ('Hou, Binyang', 1),
#  ('Hou, Xueling', 1),
#  ('Hough, David B.', 1),
#  ('Hove, Michael J.', 1),
#  ('Howard, Austin A.', 1),
#  ('Howe, L. H.', 1),
#  ('Hribar-Lee, Barbara', 1),
#  ('Hsieh, Cho-Shuen', 1),
#  ('Hu, Dan', 1),
#  ('Hu, Jimming', 1),
#  ('Hu, Jun', 1),
#  ('Hu, Longqian', 1),
#  ('Hu, Naiping', 1),
#  ('Hu, Yang-Yang', 1),
#  ('Hu, Yuan', 1),
#  ('Hua, Shugui', 1),
#  ('Hua, Wei', 1),
#  ('Hua, Weijie', 1),
#  ('Huang, Baokun', 1),
#  ('Huang, C.', 1),
#  ('Huang, Congcong', 1),
#  ('Huang, Huang-Chiao', 1),
#  ('Huang, Jiaxing', 1),
#  ('Huang, Jin', 1),
#  ('Huang, Jung-Yaw', 1),
#  ('Huang, Ningdong', 1),
#  ('Huang, Yongfeng', 1),
#  ('Huang, Zhengqing', 1),
#  ('Huang, Zishuai', 1),
#  ('Hudson, Alexander', 1),
#  ('Hug, Gordon L.', 1),
#  ('Huggins, Charles M.', 1),
#  ('Hui, Chung-Yuen', 1),
#  ('Huis, Dolf', 1),
#  ('Hujo, Waldemar', 1),
#  ('Humbert, C.', 1),
#  ('Humbert-Droz, Marie', 1),
#  ('Hung, Kuo-Kai', 1),
#  ('Hunger, Johannes', 1),
#  ('Hunnicutt, Sally S.', 1),
#  ('Huotari, Simo', 1),
#  ('Hupp, Joseph T.', 1),
#  ('Hura, Greg L.', 1),
#  ('Hurtado, Paola', 1),
#  ('Hushvaktov, H. A.', 1),
#  ('Hushvaktov, H.A.', 1),
#  ('Hussein, Salome', 1),
#  ('Hvelplund, Preben', 1),
#  ('Hwang, Choongyu', 1),
#  ('Hwang, Soyoun', 1),
#  ('Hynes, James T.', 1),
#  ('Hämäläinen, Keijo', 1),
#  ('Hänni-Ciunel, Katarzyna', 1),
#  ('Hénon, S.', 1),
#  ('Hübner, W.', 1),
#  ('Ibagon, Ingrid', 1),
#  ('Idupulapati, Nagesh', 1),
#  ('Iehl, Romain', 1),
#  ('Iglesias-Fernández, Javier', 1),
#  ('Ihee, Hyotcherl', 1),
#  ('Ikeda, N.', 1),
#  ('Ikeda, Norihiro', 1),
#  ('Ilett, Stephen M.', 1),
#  ('Imoto, Sho', 1),
#  ('Imshenetskiĭ, A A', 1),
#  ('Indekeu, Joseph', 1),
#  ('Indekeu, Joseph O.', 1),
#  ('Ingargiola, Antonino', 1),
#  ('Inoue, Ken-ichi', 1),
#  ('Inoue, Takayuki.', 1),
#  ('Institute of Mathematical Statistics, ', 1),
#  ('Irikura, Karl K.', 1),
#  ('Irudayam, Sheeba Jem', 1),
#  ('Isaac, O.', 1),
#  ('Isaji, Megumi', 1),
#  ('Ishiguro, Shin-ichi', 1),
#  ('Ishikawa, K.', 1),
#  ('Ishiyama, Tatsuya', 1),
#  ('Ismach, Ariel', 1),
#  ('Israelachvili, Jacob', 1),
#  ('Itkis, Mikhail E.', 1),
#  ('Ityaksov, D.', 1),
#  ('Ivanov, André', 1),
#  ('Iwamoto, Reikichi', 1),
#  ('Jabes, B. Shadrack', 1),
#  ('Jackman, Corine', 1),
#  ('Jacobson, Liam C.', 1),
#  ('Jacobson, Matthew P.', 1),
#  ('Jafari, Mousa', 1),
#  ('Jaffe, R. L.', 1),
#  ('Jagannadh, B.', 1),
#  ('Jagoda-Cwiklik, Barbara', 1),
#  ('Jagota, Anand', 1),
#  ('Jahani, Farahnaz', 1),
#  ('Jahn, Miriam', 1),
#  ('Jallad, Karim N.', 1),
#  ('Jamadagni, Sumanth N.', 1),
#  ('Jang, Bor Z.', 1),
#  ('Jang, Seung Soon', 1),
#  ('Janjic, Goran V.', 1),
#  ('Jannasch, Hans W.', 1),
#  ('Jansen, Thomas La Cour', 1),
#  ('Jarrold, Martin F.', 1),
#  ('Jarvis, Neldon L.', 1),
#  ('Jarzynski, Christopher', 1),
#  ('Jayakumar, V.S.', 1),
#  ('Jayathilake, Himali D.', 1),
#  ('Jeanmairet, Guillaume', 1),
#  ('Jena, Kailash C.', 1),
#  ('Jenkins, H. Donald B.', 1),
#  ('Jensen, Rebecca A.', 1),
#  ('Jeyachandran, Y. L.', 1),
#  ('Jeyachandran, Yekkoni L.', 1),
#  ('Jha, Shantenu', 1),
#  ('Ji, Minbiao', 1),
#  ('Ji, N.', 1),
#  ('Jia, Bao-Shen', 1),
#  ('Jiang, De-en', 1),
#  ('Jiang, Jie', 1),
#  ('Jiang, Peng', 1),
#  ('Jiang, Q.', 1),
#  ('Jiang, Q. G.', 1),
#  ('Jiang, Shaoyi', 1),
#  ('Jin, Shaoqing', 1),
#  ('Jin, Zhehui', 1),
#  ('Jing, Benxin', 1),
#  ('Jing, Huaiyu', 1),
#  ('Joanny, J. F.', 1),
#  ('Joe, I. Hubert', 1),
#  ('Johansson, Patrik', 1),
#  ('Johns, James E.', 1),
#  ('Johnson, A. T. Charlie', 1),
#  ('Johnson, C. Magnus', 1),
#  ('Johnson, Justin C.', 1),
#  ('Johnson, Kenneth S.', 1),
#  ('Johnson, Kevin E.', 1),
#  ('Johnson, M. E.', 1),
#  ('Johnson, Russell D.', 1),
#  ('Johnston, Andrew James', 1),
#  ('Johnston, Roy L.', 1),
#  ('Johri, Manoj', 1),
#  ('Jones, Grinnell', 1),
#  ('Jones, N. C.', 1),
#  ('Jonin, Christian', 1),
#  ('Joo, Taiha', 1),
#  ('Jordan, Kenneth D.', 1),
#  ('Jorge, Miguel', 1),
#  ('Jorgensen, William L.', 1),
#  ('Jorio, A.', 1),
#  ('Jorio, Ado', 1),
#  ('Josefsson, Ida', 1),
#  ('Joshi, Kaushik L.', 1),
#  ('Joshi, R. K.', 1),
#  ('Joutsuka, Tatsuya', 1),
#  ('Ju, Long', 1),
#  ('Ju, Shan Shan', 1),
#  ('Juanes, Ruben', 1),
#  ('Jubb, Aaron M.', 1),
#  ('Jumabaev, A.', 1),
#  ('Jun, Sunhong', 1),
#  ('Juneja, Alok', 1),
#  ('Jung, Young Mee', 1),
#  ('Junghans, Christoph', 1),
#  ('Jungwirth, Pavel', 1),
#  ('Jurečka, Petr', 1),
#  ('Juurinen, Iina', 1),
#  ('Kacker, Raghu N.', 1),
#  ('Kaganer, Vladimir M.', 1),
#  ('Kahl, H', 1),
#  ('Kahlweit, M.', 1),
#  ('Kahros, Argyris', 1),
#  ('Kalaydjian, Francois', 1),
#  ('Kaledin, Martina', 1),
#  ('Kalinin, V.V.', 1),
#  ('Kalinina, Irina', 1),
#  ('Kalishwaralal, Kalimuthu', 1),
#  ('Kamarchik, Eugene', 1),
#  ('Kamat, Prashant V', 1),
#  ('Kamat, Prashant V.', 1),
#  ('Kamath, Ganesh', 1),
#  ('Kameda, Yasuo', 1),
#  ('Kamimura, Akio', 1),
#  ('Kaminský, Jakub', 1),
#  ('Kanazawa, Masaomi', 1),
#  ('Kanazawa, Yushin', 1),
#  ('Kanduč, Matej', 1),
#  ('Kaner, Richard B.', 1),
#  ('Kang, H. C.', 1),
#  ('Kang, Seunghun', 1),
#  ('Kang, Tae Hui', 1),
#  ('Kaniwa, Keisuke', 1),
#  ('Kant, Rama', 1),
#  ('Kao, Ya-Ting', 1),
#  ('Kapteyn, Henry', 1),
#  ('Karakashev, Stoyan I.', 1),
#  ('Karam, Tony E.', 1),
#  ('Karashima, Shutaro', 1),
#  ('Karhan, Kristof', 1),
#  ('Karimi, F.', 1),
#  ('Karlický, František', 1),
#  ('Karmakar, Anwesa', 1),
#  ('Karnes, John J.', 1),
#  ('Kartashynska, Elena S.', 1),
#  ('Karttunen, Mikko', 1),
#  ('Kaser, H.', 1),
#  ('Kashimoto, Kaoru', 1),
#  ('Kaszuba, Karol', 1),
#  ('Kataoka, Sho', 1),
#  ('Katepalli, Hari', 1),
#  ('Katiyar, Ram S.', 1),
#  ('Kato, Hiroyuki S.', 1),
#  ('Katsir, Yael', 1),
#  ('Katsnelson, Mikhail I.', 1),
#  ('Katsumoto, Yukiteru', 1),
#  ('Katsuta, Shoichi.', 1),
#  ('Kauffman, John', 1),
#  ('Kauranen, M.', 1),
#  ('Kauranen, Martti', 1),
#  ('Kawagoe, Hiroaki', 1),
#  ('Kawakami, Roland K.', 1),
#  ('Kawamoto, E.', 1),
#  ('Kawase, Kodo', 1),
#  ('Kaxiras, Efthimios', 1),
#  ('Kay, Bruce D.', 1),
#  ('Kazer, Samuel W.', 1),
#  ('Keiper, Timothy D.', 1),
#  ('Keiser, Geoff', 1),
#  ('Kelleher, Colm P.', 1),
#  ('Kelley, Morgan', 1),
#  ('Kelley, P. L.', 1),
#  ('Kellogg, G.', 1),
#  ('Kelly, Daniel N.', 1),
#  ('Kent, Paul', 1),
#  ('Kenway, Owain A.', 1),
#  ('Kerdcharoen, Teerakiat', 1),
#  ('Kessel, Rüdiger', 1),
#  ('Kessler, Jan', 1),
#  ('Kestranek, Aimee', 1),
#  ('Ketteler, Guido', 1),
#  ('Khademhosseini, Ali', 1),
#  ('Khakoo, M. A.', 1),
#  ('Khan, Imran', 1),
#  ('Kherb, Jaibir', 1),
#  ('Khilar, Kartic C.', 1),
#  ('Kian Ping, Loh', 1),
#  ('Kiefer, Johannes', 1),
#  ('Kienberger, Reinhard', 1),
#  ('Kikkawa, Nobuaki', 1),
#  ('Kikteva, Tanya', 1),
#  ('Kim, Donggyu', 1),
#  ('Kim, Doseok', 1),
#  ('Kim, Evgenia', 1),
#  ('Kim, Franklin', 1),
#  ('Kim, Heejae', 1),
#  ('Kim, Hye-Young', 1),
#  ('Kim, Jaemyung', 1),
#  ('Kim, Jedeok', 1),
#  ('Kim, Jeongho', 1),
#  ('Kim, Joonyeong', 1),
#  ('Kim, Jun Soo', 1),
#  ('Kim, K.', 1),
#  ('Kim, Kwang S.', 1),
#  ('Kim, Kwanpyo', 1),
#  ('Kim, Mahn Won', 1),
#  ('Kim, MahnWon', 1),
#  ('Kim, Philip', 1),
#  ('Kim, Seung Bin', 1),
#  ('Kim, Young-Kwan', 1),
#  ('Kimmel, Greg A.', 1),
#  ('Kindt, James T.', 1),
#  ('King, Sarah B.', 1),
#  ('Kirchner, Barbara', 1),
#  ('Kizhakevariam, N', 1),
#  ('Kleyn, Aart W.', 1),
#  ('Klimchitskaya, G. L.', 1),
#  ('Klimeš, Jiří', 1),
#  ('Kloepfer, Jeremiah A.', 1),
#  ('Knapp, Ernst Walter', 1),
#  ('Knecht, V.', 1),
#  ('Knezevic, I.', 1),
#  ('Knock, Mona Marie', 1),
#  ('Knop, Stephan', 1),
#  ('Knutsen, Kelly P.', 1),
#  ('Ko, Taeg Yeoung', 1),
#  ('Kobayashi, Kei', 1),
#  ('Koch, Henrik', 1),
#  ('Kockaert, Pascal', 1),
#  ('Kocman, Mikuláš', 1),
#  ('Koga, Kenichiro', 1),
#  ('Koga, Yoshikata', 1),
#  ('Kogar, Anshul', 1),
#  ('Kohlmeyer, Axel', 1),
#  ('Kokkoli, Efrosini', 1),
#  ('Kolandaivel, P.', 1),
#  ('Kolbe, M.', 1),
#  ('Koller, G.', 1),
#  ('Kollman, Peter A.', 1),
#  ('Kolodezny, Dmitry', 1),
#  ('Komurasaki, Hiroki', 1),
#  ('Konek, Christopher T.', 1),
#  ('Konelick, Nicole', 1),
#  ('Konovalov, O.', 1),
#  ('Konovalov, Oleg', 1),
#  ('Konovalov, Oleg V.', 1),
#  ('Koo, Chee Keong', 1),
#  ('Koplik, Joel', 1),
#  ('Kopylov, D. A.', 1),
#  ('Koratkar, Nikhil', 1),
#  ('Koratkar, Nikhil A.', 1),
#  ('Kornev, Igor A.', 1),
#  ('Korniyenko, Y.', 1),
#  ('Kornyshev, A.A.', 1),
#  ('Kosugi, Nobuhiro', 1),
#  ('Kou, Ran', 1),
#  ('Koumoutsakos, P.', 1),
#  ('Kowall, Thomas.', 1),
#  ('Kowert, Bruce A.', 1),
#  ('Kraack, H.', 1),
#  ('Kraack, Jan Philip', 1),
#  ('Kraft, Matthias', 1),
#  ('Krakowiak, Joanna', 1),
#  ('Kralchevsky, Peter A.', 1),
#  ('Krasowska, M.', 1),
#  ('Krausz, Ferenc', 1),
#  ('Kravets, Vasyl G.', 1),
#  ('Kremer, Kurt', 1),
#  ('Kretzschmar, Ilona', 1),
#  ('Krisch, Maria J.', 1),
#  ('Krishnatreya, Bhaskar Jyoti', 1),
#  ('Krishtal, Alisa', 1),
#  ('Kritzinger, Christo', 1),
#  ('Krongsuk, Sriprajak', 1),
#  ('Krueger, P. J.', 1),
#  ('Kruk, Jennifer J.', 1),
#  ('Král, Petr', 1),
#  ('Krüger, Peter', 1),
#  ('Kubelka, Jan', 1),
#  ('Kubicek, Katharina', 1),
#  ('Kubisiak, Piotr', 1),
#  ('Kudin, Konstantin N.', 1),
#  ('Kudo, Tetsuichi', 1),
#  ('Kulakov, T. A.', 1),
#  ('Kulig, Waldemar', 1),
#  ('Kulik, Heather J.', 1),
#  ('Kulmala, T. S.', 1),
#  ('Kumal, Raju R.', 1),
#  ('Kumar, Pardeep', 1),
#  ('Kumar, Revati', 1),
#  ('Kumar, Shankar', 1),
#  ('Kumpulainen, Atte', 1),
#  ('Kundacina, Nenad', 1),
#  ('Kundu, Achintya', 1),
#  ('Kunieda, Makoto', 1),
#  ('Kunz, W.', 1),
#  ('Kuo, I-Feng W.', 1),
#  ('Kuo, I-Feng William', 1),
#  ('Kuo, I.-F. William', 1),
#  ('Kuo, Margaret', 1),
#  ('Kurahashi, Naoya', 1),
#  ('Kuran, Bryan A.', 1),
#  ('Kuroda, Daniel G.', 1),
#  ('Kurtén, Theo', 1),
#  ('Kusaka, Ryoji', 1),
#  ('Kusalik, Peter G.', 1),
#  ('Kusanagi, Hiroshi', 1),
#  ('Kuyucak, Serdar', 1),
#  ('Kuzmenko, A. B.', 1),
#  ('Kuzmenko, Ivan', 1),
#  ('Kuznetsov, Volodymyr', 1),
#  ('Kuznicki, N. P.', 1),
#  ('Kwak, Kyungwon', 1),
#  ('Kwok, Sheldon J. J.', 1),
#  ('Kwok, Sheldon J.J.', 1),
#  ('Kwon, Oh-Sun', 1),
#  ('Kyaw, Htet H', 1),
#  ('Köhler, Jürgen', 1),
#  ('Kühne, Thomas D.', 1),
#  ('Küstner, Bernd', 1),
#  ('LaViolette, Randall A.', 1),
#  ('Laage, Damien', 1),
#  ('Laanait, Nouamane', 1),
#  ('Laaser, Jennifer E.', 1),
#  ('Lachet, Véronique', 1),
#  ('Ladanyi, Branka M.', 1),
#  ('Laggner, Peter', 1),
#  ('Laidlaw, W. G.', 1),
#  ('Laksmono, H.', 1),
#  ('Lambert, Alex G.', 1),
#  ('Lange, Adrian W.', 1),
#  ('Lange, Kathrin M.', 1),
#  ('Langford, Joel', 1),
#  ('Lanning, Oliver J.', 1),
#  ('Lanzara, Alessandra', 1),
#  ('Lassègues, Jean-Claude', 1),
#  ('Latimer, Wendell M.', 1),
#  ('Law, Bruce M.', 1),
#  ('Lawrence, C.', 1),
#  ('Lazar, Petr', 1),
#  ('Le, Duc Thanh', 1),
#  ('Le, Thu N.', 1),
#  ('Leach, Gary W.', 1),
#  ('Lee, Alpha A.', 1),
#  ('Lee, Jeong Yong', 1),
#  ('Lee, Jonggwan', 1),
#  ('Lee, Joohyung', 1),
#  ('Lee, Ka Yee C.', 1),
#  ('Lee, Touk-kwan', 1),
#  ('Leenaerts, O.', 1),
#  ('Legrand, J. F.', 1),
#  ('Lei, Q.', 1),
#  ('Lei, Qunfang', 1),
#  ('Leich, Megan A.', 1),
#  ('Leiserowitz, Leslie', 1),
#  ('Leitenberger, W.', 1),
#  ('Lemaire, J.J.', 1),
#  ('Lenchenkov, Victor A.', 1),
#  ('Leopold, Ken', 1),
#  ('Lessner, E.', 1),
#  ('Letrun, Romain', 1),
#  ('Leung, Andy H. M.', 1),
#  ('Levering, Lori M.', 1),
#  ('Levesque, Maximilien', 1),
#  ('Levin, Yan', 1),
#  ('Levitin, Daniel J.', 1),
#  ('Levitov, Leonid S.', 1),
#  ('Levitt, Michael', 1),
#  ('Lewis, B D', 1),
#  ('Lewis, David F. V.', 1),
#  ('Lewis, W. C. M.', 1),
#  ('Leyte, J.C.', 1),
#  ('Leyte, Jaap C.', 1),
#  ('Li, Bofu', 1),
#  ('Li, Can', 1),
#  ('Li, Feng', 1),
#  ('Li, Guixin', 1),
#  ('Li, Hang', 1),
#  ('Li, Hong', 1),
#  ('Li, Hui', 1),
#  ('Li, Isaac T. S.', 1),
#  ('Li, Jialin', 1),
#  ('Li, Jicun', 1),
#  ('Li, Jiebo', 1),
#  ('Li, Jingyuan', 1),
#  ('Li, Libo', 1),
#  ('Li, Ming', 1),
#  ('Li, Na', 1),
#  ('Li, Peixun X.', 1),
#  ('Li, Qiang', 1),
#  ('Li, Ruoyu', 1),
#  ('Li, Sheng', 1),
#  ('Li, Shuhua', 1),
#  ('Li, Wei', 1),
#  ('Li, Weifeng', 1),
#  ('Li, Weiqi', 1),
#  ('Li, Xiaoxia', 1),
#  ('Li, Xin', 1),
#  ('Li, Xin-Xue', 1),
#  ('Li, Xin-Zheng', 1),
#  ('Li, Z. X.', 1),
#  ('Li, Zhi-Ru', 1),
#  ('Liang, Chungwen', 1),
#  ('Liang, Yunfeng', 1),
#  ('Lianos, L.', 1),
#  ('Lichtenstein, Alexander I.', 1),
#  ('Lieber, Charles M.', 1),
#  ('Light, Taylor P.', 1),
#  ('Lightcap, Ian V.', 1),
#  ('Lim, Soon-Mi', 1),
#  ('Limmer, David T.', 1),
#  ('Limão-Vieira, P.', 1),
#  ('Lin, Binhua', 1),
#  ('Lin, Deng-Sung', 1),
#  ('Lin, Dian-Yang', 1),
#  ('Lin, Lu', 1),
#  ('Lin, Sheng Hsien.', 1),
#  ('Lin, Shiang-Tai', 1),
#  ('Lin, Shuang', 1),
#  ('Lin, Xiang', 1),
#  ('Lindberg, Gerrick E.', 1),
#  ('Lindner, Jorg', 1),
#  ('Lindner, Jörg', 1),
#  ('Lindsay, L.', 1),
#  ('Lineberger, W. Carl', 1),
#  ('Link, D. R.', 1),
#  ('Linnartz, H.', 1),
#  ('Linse, Per', 1),
#  ('Liou, Jia-Jiunn', 1),
#  ('Lipowsky, Reinhard', 1),
#  ('Lippert, Andreas', 1),
#  ('Lippitz, M.', 1),
#  ('Lisy, James M.', 1),
#  ('Little, Reginald B.', 1),
#  ('Liu, Chen', 1),
#  ('Liu, Cheng-Wen', 1),
#  ('Liu, Chenguang', 1),
#  ('Liu, Dingfang', 1),
#  ('Liu, Guangming', 1),
#  ('Liu, Jian', 1),
#  ('Liu, Maoyuan', 1),
#  ('Liu, Minghua', 1),
#  ('Liu, Shuhai', 1),
#  ('Liu, W.-T.', 1),
#  ('Liu, Wei', 1),
#  ('Liu, Xiang', 1),
#  ('Liu, Xinmin', 1),
#  ('Liu, Yan', 1),
#  ('Liu, Yang', 1),
#  ('Liu, Yong', 1),
#  ('Liu, Yuanyue', 1),
#  ('Liu, Zhipei', 1),
#  ('Liu, Zhongyi', 1),
#  ('Livingstone, Ruth A.', 1),
#  ('Llanio-Trujillo, J. L.', 1),
#  ('Lo Nostro, P.', 1),
#  ('Loahardjo, Nina', 1),
#  ('Loethen, Yvette', 1),
#  ('Lofwander, T.', 1),
#  ('Logan, Jennifer', 1),
#  ('Loh, Kian Ping', 1),
#  ('Loh, N. D.', 1),
#  ('Loh, Zhi-Heng', 1),
#  ('Loidl, A.', 1),
#  ('Loison, Claire', 1),
#  ('Lokki, Tapio', 1),
#  ('Lombardo, A.', 1),
#  ('Longo, Ricardo Luiz', 1),
#  ('Loparo, J. J.', 1),
#  ('Lorenz, Christian D.', 1),
#  ('Lotti, Davide', 1),
#  ('Lotze, Stephan', 1),
#  ('Lou, Xiu-Tao', 1),
#  ('Louie, Steven G.', 1),
#  ('Lo¨fgren, Ha˚kan', 1),
#  ('Lu, J. R.', 1),
#  ('Lu, Peng', 1),
#  ('Lu, Rong', 1),
#  ('Lu, Zhi-Wei', 1),
#  ('Lu, Zhou', 1),
#  ('Lubcke, Andrea', 1),
#  ('Luca, Alfio A. Tamburello', 1),
#  ('Lue, Leo', 1),
#  ('Luftner, D.', 1),
#  ('Lui, Chun Hung', 1),
#  ('Lukšič, Miha', 1),
#  ('Lum, Ka', 1),
#  ('Lund, Mikael', 1),
#  ('Lunkenheimer, K.', 1),
#  ('Lunkenheimer, P.', 1),
#  ('Luo, G.', 1),
#  ('Luo, Jianbin', 1),
#  ('Luo, Yu', 1),
#  ('Lupi, Laura', 1),
#  ('Lusceac, S. A.', 1),
#  ('Lv, Kai', 1),
#  ('Lyding, Joseph W.', 1),
#  ('Lynden-Bell, R. M.', 1),
#  ('Lynden-Bell, Ruth M.', 1),
#  ('López de Ramos, A. L.', 1),
#  ('Lösche, Mathias', 1),
#  ('Lütgebaucks, Cornelis', 1),
#  ('Ma, C. Derek', 1),
#  ('Ma, Gang', 1),
#  ('Ma, Jing', 1),
#  ('Ma, Ming', 1),
#  ('Ma, Xiu-Xiu', 1),
#  ('Ma, Ying-Zhong', 1),
#  ('MacDonald, Gina', 1),
#  ('MacDowell, L. G.', 1),
#  ('MacKerell, Alexander D.', 1),
#  ('Machado, Matías R.', 1),
#  ('Macias-Romero, Carlos', 1),
#  ('Madden, Paul', 1),
#  ('Madden, Paul A.', 1),
#  ('Madeira, Pedro', 1),
#  ('Madey, Theodore E.', 1),
#  ('Mafuné, Fumitaka', 1),
#  ('Magnuson, Carl W.', 1),
#  ('Mago, Deesha D.', 1),
#  ('Mahadevi, A. Subha', 1),
#  ('Mahmood, Ather', 1),
#  ('Mahurin, Shannon M.', 1),
#  ('Maier, S. A.', 1),
#  ('Maier, Sabine', 1),
#  ('Maiti, Prabal K.', 1),
#  ('Maity, Surajit', 1),
#  ('Mak, Chun C.', 1),
#  ('Mak, Kin Fai', 1),
#  ('Makowski, Michael J.', 1),
#  ('Malard, L.M.', 1),
#  ('Malberg, Friedrich', 1),
#  ('Maldarelli, Charles', 1),
#  ('Malfreyt, Patrice', 1),
#  ('Mallet, Pierre', 1),
#  ('Mamatkulov, Shavkat I.', 1),
#  ('Mamontov, Eugene', 1),
#  ('Manas, Eric S.', 1),
#  ('Mancini, Giordano', 1),
#  ('Manciu, Marian', 1),
#  ('Mandal, Aritra', 1),
#  ('Manen, Henk-Jan van', 1),
#  ('Manfred, Katherine', 1),
#  ('Mani, A.A.', 1),
#  ('Manly, Bryan F. J.', 1),
#  ('Manoharan, Vinothan N.', 1),
#  ('Mansson, R.A.', 1),
#  ('Mantle, Michael D.', 1),
#  ('Mantsyzov, B. I.', 1),
#  ('Marchetti, Mario', 1),
#  ('Marcotulli, Federica', 1),
#  ('Marcus, Y.', 1),
#  ('Marcus, Yizhak', 1),
#  ('Margarella, Alexandria M.', 1),
#  ('Marichev, V. A.', 1),
#  ('Marie, Céline', 1),
#  ('Mark, A.E.', 1),
#  ('Markin, V.S.', 1),
#  ('Markovich, Tomer', 1),
#  ('Marmur, Abraham', 1),
#  ('Marowsky, G.', 1),
#  ('Marques, J. M. C.', 1),
#  ('Marrink, S.J.', 1),
#  ('Marshall, Bennett D.', 1),
#  ('Martelli, Fausto', 1),
#  ('Martens, Craig C.', 1),
#  ('Marti, J.', 1),
#  ('Martin, A. V.', 1),
#  ('Martin, Michael', 1),
#  ('Martin, Michael C.', 1),
#  ('Martin, Olivier J. F.', 1),
#  ('Martinez, Juan Andres', 1),
#  ('Martiniano, H. F. M. C.', 1),
#  ('Martiniano, Hugo F. M. C.', 1),
#  ('Martins-Costa, M.', 1),
#  ('Martins-Costa, Marilia T. C.', 1),
#  ('Martinson, Alex B. F.', 1),
#  ('Martín, M. Elena', 1),
#  ('Martínez-Haya, Bruno', 1),
#  ('Martz, Todd R.', 1),
#  ('Martí, J', 1),
#  ('Martín-Romero, María T.', 1),
#  ('Martínez-Ruiz, F. J.', 1),
#  ('Marucho, Marcelo', 1),
#  ('Marx, Alexander', 1),
#  ('Marx, B.', 1),
#  ('Marzari, Nicola', 1),
#  ('Masciovecchio, Claudio', 1),
#  ('Maselko, Jerzy', 1),
#  ('Maselli, Olivia', 1),
#  ('Masia, Marco', 1),
#  ('Masliyah, J.', 1),
#  ('Mason, N. J.', 1),
#  ('Mason, P. E.', 1),
#  ('Mason, Phil E.', 1),
#  ('Massar, Serge', 1),
#  ('Mata, Jitendra P.', 1),
#  ('Mathlouthi, Mohamed', 1),
#  ('Matile, Stefan', 1),
#  ('Matin, Md. Ruhul', 1),
#  ('Matousek, Pavel', 1),
#  ('Matsubara, H.', 1),
#  ('Matsubara, Hiroki', 1),
#  ('Matsuda, Takashi', 1),
#  ('Matsuda, Toshihiko', 1),
#  ('Matsumoto, Masakazu', 1),
#  ('Matsumoto, Shimako', 1),
#  ('Matsuoka, Hideki', 1),
#  ('Matsuoka, Toshifumi', 1),
#  ('Matsushige, Kazumi', 1),
#  ('Matsuura, Hiroatsu', 1),
#  ('Matsuzaki, Korenobu', 1),
#  ('Matt, Sarah M.', 1),
#  ('Matthiesen, Jesper', 1),
#  ('Matubayasi, Nobuyuki', 1),
#  ('Matuura, Ryohei', 1),
#  ('Matzger, Adam J.', 1),
#  ('Mausbach, Peter.', 1),
#  ('May, R. Alan', 1),
#  ('Mayer, István', 1),
#  ('Maze, Joshua T.', 1),
#  ('Mazighi, Redha', 1),
#  ('McArthur, Eric A.', 1),
#  ('McCabe, Clare', 1),
#  ('McCarty, Kevin F.', 1),
#  ('McClary, Felicia', 1),
#  ('McCluan, Jennifer', 1),
#  ('McCoy, Anne B.', 1),
#  ('McDonough, John', 1),
#  ('McFearin, Cathryn L.', 1),
#  ('McGillivray, Duncan J.', 1),
#  ('McGregor, James', 1),
#  ('McGuire, John A.', 1),
#  ('McKenzie, S.', 1),
#  ('McKinley, Gareth H.', 1),
#  ('McLain, Sylvia', 1),
#  ('McLain, Sylvia E.', 1),
#  ('McNab, J. R.', 1),
#  ('McQueen, T. A.', 1),
#  ('McQuillan, A. James', 1),
#  ('McWilliams, Laura E.', 1),
#  ('Mecke, M', 1),
#  ('Medasani, Bharat', 1),
#  ('Meech, S. R.', 1),
#  ('Mehandzhiyski, Aleksandar Y.', 1),
#  ('Meisel, Dan', 1),
#  ('Meister, Konrad', 1),
#  ('Mendes, B.', 1),
#  ('Mendoza, Nubia Judith', 1),
#  ('Meng, Sheng', 1),
#  ('Menon, Vinod', 1),
#  ('Merano, Michele', 1),
#  ('Mercury, Lionel', 1),
#  ('Merlet, Céline', 1),
#  ('Meron, Mati', 1),
#  ('Merzel, Franci', 1),
#  ('Messer, Benjamin M.', 1),
#  ('Messerschmidt, M.', 1),
#  ('Metrick, Michael A.', 1),
#  ('Meunier, J.', 1),
#  ('Meunier, Jacques', 1),
#  ('Meyer, F.', 1),
#  ('Meyer, Frank', 1),
#  ('Meyer-ter-Vehn, J.', 1),
#  ('Mezger, Markus', 1),
#  ('Mi, Xi', 1),
#  ('Michaelides, Angelos', 1),
#  ('Michaels, R.', 1),
#  ('Michel, Carine', 1),
#  ('Michelsen, Rebecca R. H.', 1),
#  ('Migliorati, Valentina', 1),
#  ('Mihaylov, Miroslav', 1),
#  ('Milet, Anne', 1),
#  ('Miller, Abigail E.', 1),
#  ('Miller, Clarence A.', 1),
#  ('Miller, Foil A.', 1),
#  ('Miller, Jan D.', 1),
#  ('Miller, Mark A.', 1),
#  ('Miller, Roger E.', 1),
#  ('Min, Dal-Hee', 1),
#  ('Minofar, Babak', 1),
#  ('Miragliotta, J.', 1),
#  ('Miranda, Caetano R.', 1),
#  ('Mishra, Himanshu', 1),
#  ('Mitchell, James W', 1),
#  ('Mitrinović, Dragoslav M.', 1),
#  ('Miyakubo, Keisuke', 1),
#  ('Mizrahi, Victor', 1),
#  ('Mizuno, Tomoya', 1),
#  ('Mizuse, Kenta', 1),
#  ('Mišković, Z. L.', 1),
#  ('Mjalli, F. S.', 1),
#  ('Mo, Sung-Kwan', 1),
#  ('Mohan, Sadhana', 1),
#  ('Mokhtari, Tahereh', 1),
#  ('Molinero, Valeria', 1),
#  ('Monaco, Giulio', 1),
#  ('Monahan, John F.', 1),
#  ('Mondal, Jahur A.', 1),
#  ('Mondal, Subrata', 1),
#  ('Mondal, Sudip Kumar', 1),
#  ('Monduzzi, Maura', 1),
#  ('Monroe, Charles', 1),
#  ('Mookherji, A.', 1),
#  ('Moore, Fred G.', 1),
#  ('Morag, Jonathan', 1),
#  ('Moreira, Francisco George Brady', 1),
#  ('Morgner, Harald', 1),
#  ('Mori, T.', 1),
#  ('Morita, Akihiro', 1),
#  ('Moroff, G', 1),
#  ('Moroi, Yoshikiyo', 1),
#  ('Morresi, Assunta', 1),
#  ('Morrow, Andrew R.', 1),
#  ('Morrow, Norman R.', 1),
#  ('Mosquera-Vázquez, Sandra', 1),
#  ('Mostepanenko, V. M.', 1),
#  ('Motomura, Kinsi', 1),
#  ('Motschmann, H.', 1),
#  ('Motulsky, Harvey', 1),
#  ('Moutinho, M. V. O.', 1),
#  ('Mucha, Martin', 1),
#  ('Mugele, F.', 1),
#  ('Muhammad, Shabbir', 1),
#  ('Mukamel, Shaul', 1),
#  ('Mukherji, Debashish', 1),
#  ('Mulliken, Robert S.', 1),
#  ('Mun, Bongjin Simon', 1),
#  ('Munakata, Toshiaki', 1),
#  ('Mundy, Christopher J.', 1),
#  ('Muñoz-Losa, Aurora', 1),
#  ('Murgia, Sergio', 1),
#  ('Murnane, Margaret', 1),
#  ('Murzina, T. V.', 1),
#  ('Musorrafiti, Michael J.', 1),
#  ('Mutihac, Radu-Cristian', 1),
#  ('Méndez-Morales, Trinidad', 1),
#  ('Mériguet, Guillaume', 1),
#  ('Möhwald, Helmuth', 1),
#  ('Müllen, Klaus', 1),
#  ('Müller, J. P.', 1),
#  ('Müller, Lars', 1),
#  ('Müller, Michiel', 1),
#  ('NATO Advanced Study Institute, ', 1),
#  ('Naahidi, Sheva', 1),
#  ('Nadermann, Nichole', 1),
#  ('Nafie, Laurence A.', 1),
# ...
#  ('Stutzmann, M.', 1),
#  ('Stutzmann, Martin', 1),
#  ('Stuve, E. M.', 1),
#  ('Stähler, Julia', 1),
#  ('Støchkel, Kristian', 1),
#  ('Su, Xin', 1),
#  ('Su, Xingcai', 1),
#  ('Su, Xueju', 1),
#  ('Su, Ying', 1),
#  ('Su, Zhong-Min', 1),
#  ('Subinya, Mireia', 1),
#  ('Subir, Mahamud', 1),
#  ('Subrahmanyam, K.S.', 1),
#  ('Subramanian, S.', 1),
#  ('Suchomel, M', 1),
#  ('Sudnik, Leo M.', 1),
#  ('Suganuma, H.', 1),
#  ('Sugita, Yuji', 1),
#  ('Suhm, Martin A.', 1),
#  ('Sulpizi, Marialore', 1),
#  ('Sumi, Tomonari', 1),
#  ('Sun, Lu', 1),
#  ('Sun, Qinchao', 1),
#  ('Sun, Shi-Ling', 1),
#  ('Sun, Shumei', 1),
#  ('Sun, Xiudong', 1),
#  ('Sun, Xiuquan', 1),
#  ('Sun, Yuan-yuan', 1),
#  ('Sun, Yueming', 1),
#  ('Sun, Zheng', 1),
#  ('Sundstrom, E. J.', 1),
#  ('Sung, Woongmo', 1),
#  ('Surwade, Sumedh P.', 1),
#  ('Sushko, Maria L.', 1),
#  ('Suzuki, Kazuhiro', 1),
#  ('Suzuki, Toshinori', 1),
#  ('Suzuki, Yoshi-Ichi', 1),
#  ('Svanberg, C.', 1),
#  ('Svechkarev, Denis', 1),
#  ('Svyakhovskiy, S. E.', 1),
#  ('Swails, Jason M.', 1),
#  ('Swendsen, Robert H.', 1),
#  ('Swenson, J.', 1),
#  ('Szilagyi, Istvan', 1),
#  ('Szklarczyk, Oliwia M.', 1),
#  ('Szleifer, Igal', 1),
#  ('Sá, ', 1),
#  ('Śmiechowski, Maciej', 1),
#  ('THOMAS, Jr.', 1),
#  ('TSUBOI, Masamichi', 1),
#  ('Tabor, Daniel P.', 1),
#  ('Tachikake, Miyuki', 1),
#  ('Tadjeddine, Abderrahmane', 1),
#  ('Tadjer, Marko', 1),
#  ('Tadmor, Rafael', 1),
#  ('Taguchi, Masataka', 1),
#  ('Taha, Mohamed', 1),
#  ('Tahara, Tahei', 1),
#  ('Tainter, Craig J.', 1),
#  ('Takahashi, Masayoshi', 1),
#  ('Takahashi, Satoru', 1),
#  ('Takamura, Koichi', 1),
#  ('Takanishi, Y.', 1),
#  ('Takata, Y.', 1),
#  ('Takata, Youichi', 1),
#  ('Takeda, Yasuyuki', 1),
#  ('Takeuchi, Munetaka', 1),
#  ('Takezoe, H.', 1),
#  ('Takiue, T.', 1),
#  ('Takiue, Takanori', 1),
#  ('Tamam, L.', 1),
#  ('Tamam, Lilach', 1),
#  ('Tamiaki, Hitoshi', 1),
#  ('Tan, Cheng', 1),
#  ('Tan, See-Hua', 1),
#  ('Tanaka, Shogo', 1),
#  ('Tandon, S. P.', 1),
#  ('Tanelian, D.L.', 1),
#  ('Tang, Cheng Y.', 1),
#  ('Tang, H.', 1),
#  ('Tang, Tsung-Ta', 1),
#  ('Tang, Ying', 1),
#  ('Tang, Yongchun', 1),
#  ('Tanida, Hajime', 1),
#  ('Tarazona, Pedro', 1),
#  ('Tauler, Roma.', 1),
#  ('Tautz, F. S.', 1),
#  ('Tavan, Paul', 1),
#  ('Tay, Kafui', 1),
#  ('Taylor, Christopher D.', 1),
#  ('Techert, Simone', 1),
#  ('Teixeira, Jose', 1),
#  ('Teixeira, José', 1),
#  ('Telle, H. H.', 1),
#  ('Tereshin, Oleg G.', 1),
#  ('Terry, Ann E.', 1),
#  ('Tervo, Sakari', 1),
#  ('Thibado, P. M.', 1),
#  ('Thiel, Patricia A.', 1),
#  ('Thiemer, K.', 1),
#  ('Thiry, P.A.', 1),
#  ('Thisayukta, J.', 1),
#  ('Thomas, Abhay V.', 1),
#  ('Thomas, Dennis G.', 1),
#  ('Thomas, R. K.', 1),
#  ('Thomas, Robert K.', 1),
#  ('Thompson, Ward H.', 1),
#  ('Thong, John T. L.', 1),
#  ('Thormann, Esben', 1),
#  ('Tian, C.', 1),
#  ('Tian, C. S.', 1),
#  ('Tian, Chuan-Shan', 1),
#  ('Tian, Chuanshan', 1),
#  ('Tian, Rui', 1),
#  ('Tian, Wei Quan', 1),
#  ('Tian, Xiaojuan', 1),
#  ('Tian, Zhong-Qun', 1),
#  ('Tielrooij, K. J.', 1),
#  ('Tielrooij, K.-J.', 1),
#  ('Tielrooij, Klaas-Jan', 1),
#  ('Tikanen, Alex C.', 1),
#  ('Tikhonov, Aleksey', 1),
#  ('Tikhonov, Aleksey M.', 1),
#  ('Timerghazin, Qadir K.', 1),
#  ('Timmons, Adam', 1),
#  ('Titantah, John Tatini', 1),
#  ('Tiwari, Akhilesh', 1),
#  ('Tobias, Douglas J.', 1),
#  ('Tocci, Gabriele', 1),
#  ('Tokmakoff, A.', 1),
#  ('Tokmakoff, Andrei', 1),
#  ('Tomisic, Vladislav', 1),
#  ('Tomlinson-Phillips, J.', 1),
#  ('Tomlinson-Phillips, Jill', 1),
#  ('Tomé, Luciana I. N.', 1),
#  ('Tong, Hai-Jie', 1),
#  ('Tong, Shi Wun', 1),
#  ('Tongraar, Anan', 1),
#  ('Torii, Hajime', 1),
#  ('Torres-Salgado, Jose F.', 1),
#  ('Toyomasu, Takayuki', 1),
#  ('Trainor, Laurel J.', 1),
#  ('Tran, Diana N. H.', 1),
#  ('Trefalt, Gregor', 1),
#  ('Treuel, L.', 1),
#  ('Trinh, Thuat T.', 1),
#  ('Tripathi, Saroj Raman', 1),
#  ('Troxler, Thomas', 1),
#  ('Troyanova-Wood, M. A.', 1),
#  ('Trudeau, Travis G.', 1),
#  ('Truskett, Thomas M.', 1),
#  ('Tröster, Philipp', 1),
#  ('Tsai, Hsin-Zon', 1),
#  ('Tschumper, Gregory S.', 1),
#  ('Tse, Ying-Lung Steve', 1),
#  ('Tsekov, Roumen', 1),
#  ('Tsen, Adam W.', 1),
#  ('Tsukamoto, Takahiro', 1),
#  ('Tsukube, Hiroshi', 1),
#  ('Tu, Yaoquan', 1),
#  ('Tucker, Ian', 1),
#  ('Tukhvatullin, F. H.', 1),
#  ('Tukhvatullin, F.H.', 1),
#  ('Turi, László', 1),
#  ('Turner, Hannah J.', 1),
#  ('Turner, Robin F. B.', 1),
#  ('Turro, Nicholas J.', 1),
#  ('Tutuc, Emanuel', 1),
#  ('Tyliszczak, Tolek', 1),
#  ('Tyrode, Eric', 1),
#  ('Ubachs, W.', 1),
#  ('Uchoa, Bruno', 1),
#  ('Uddin, Mohammad Hemayet.', 1),
#  ('Ueda, Akira', 1),
#  ('Uejio, Janel S.', 1),
#  ('Uggerud, Einar', 1),
#  ('Uhlig, Frank', 1),
#  ('Ules, T.', 1),
#  ('Ullmann, G. Matthias', 1),
#  ('Umebayashi, Yasuhiro', 1),
#  ('Underwood, A. L.', 1),
#  ('Underwood, Robin', 1),
#  ('Université scientifique et médicale de Grenoble, ', 1),
#  ('Unocic, Raymond R.', 1),
#  ('Urbakh, M.', 1),
#  ('Urbic, Tomaz', 1),
#  ('Uryu, Shozo', 1),
#  ('Usarov, A.', 1),
#  ('Ushijima, Baku', 1),
#  ('Usui, Kota', 1),
#  ('Utiramerur, S.', 1),
#  ('Vaida, Veronica', 1),
#  ('Vaikuntanathan, Suriyanarayanan', 1),
#  ('Vaknin, David', 1),
#  ('Valal, Dorit', 1),
#  ('Valiev, Marat', 1),
#  ('Valiskó, Mónika', 1),
#  ('Vallejos, Margarita M.', 1),
#  ('Valley, Nicholas A.', 1),
#  ('Valsaraj, K', 1),
#  ('Valsaraj, Kalliat T.', 1),
#  ('Van Duyne, Richard P.', 1),
#  ('Van Oss, Carel J.', 1),
#  ('Van Ryswyk, Hal', 1),
#  ('Vanderkooi, Jane M.', 1),
#  ('Vandewal, Koen', 1),
#  ('Vanselous, Heather', 1),
#  ('Vanýsek, Petr', 1),
#  ('Varela, Luis M.', 1),
#  ('Varghese, Joseph O.', 1),
#  ('Varilly, Patrick', 1),
#  ('Vattulainen, Ilpo', 1),
#  ('Vauthey, Eric', 1),
#  ('Vazdar, Mario', 1),
#  ('Vácha, Robert', 1),
#  ('Veith, Gabriel M.', 1),
#  ('Velarde, Luis', 1),
#  ('Velasco-Velez, J.-J.', 1),
#  ('Vembanur, Srivathsan', 1),
#  ('Vemparala, Satyavani', 1),
#  ('Venkata Rao, K.', 1),
#  ('Venkateshwaran, Vasudevan', 1),
#  ('Verdaguer, A.', 1),
#  ('Verdaguer, Albert', 1),
#  ('Vergara-Jaque, Ariela', 1),
#  ('Vermeulen, N.', 1),
#  ('Verreault, Dominique', 1),
#  ('Versluis, Jan', 1),
#  ('Veuillen, Jean-Yves', 1),
#  ('Vidal, Franck', 1),
#  ('Videa, Marcelo V.', 1),
#  ('Vieceli, John', 1),
#  ('Vijayakumar, S.', 1),
#  ('Vila Verde, Ana', 1),
#  ('Vilchiz, Victor H.', 1),
#  ('Vilker, Vincent', 1),
#  ('Villagrana-Escareño, Maria V.', 1),
#  ('Villard, Arnaud', 1),
#  ('Villarreal, Oscar D.', 1),
#  ('Vinaykin, Mikhail', 1),
#  ('Vincent, Jordan C.', 1),
#  ('Vinogradov, S. N.', 1),
#  ('Virally, Stéphane', 1),
#  ('Visser, J.', 1),
#  ('Viswanath, P.', 1),
#  ('Vlassiouk, Ivan V.', 1),
#  ('Vlcek, Lukas', 1),
#  ('Voets, Ilja K.', 1),
#  ('Vogel, M.', 1),
#  ('Vogel, Viola', 1),
#  ('Vohringer, Peter', 1),
#  ('Volkov, A.G.', 1),
#  ('Vollhardt, Dieter', 1),
#  ('Von der Linde, D.', 1),
#  ('Voora, Vamsee K.', 1),
#  ('Voth, Gregory A.', 1),
#  ('Vöhringer, Peter', 1),
#  ('Vrbka, Lubos', 1),
#  ('Vrhovsek, A.', 1),
#  ('Vysotsky, Yuri B.', 1),
#  ('Vácha, Robert', 1),
#  ('WILCOX, DAVID SCOTT', 1),
#  ('Wads�, Ingemar', 1),
#  ('Wagner, Manfred', 1),
#  ('Wagner, Stefanie', 1),
#  ('Wahab, Shaheda A.', 1),
#  ('Wales, D. J.', 1),
#  ('Walker, Brent', 1),
#  ('Walker, Dave S.', 1),
#  ('Walker, Gilbert C.', 1),
#  ('Walker, Rachel L.', 1),
#  ('Walker, Robert A.', 1),
#  ('Walrafen, G. E.', 1),
#  ('Walther, J. H.', 1),
#  ('Waluyo, Iradwikanari', 1),
#  ('Wan, Hongbin', 1),
#  ('Wan, L. F.', 1),
#  ('Wan, Quan', 1),
#  ('Wander, Matthew', 1),
#  ('Wang, Anna', 1),
#  ('Wang, Boyang', 1),
#  ('Wang, Chenxuan', 1),
#  ('Wang, Chuangye', 1),
#  ('Wang, Chunlei', 1),
#  ('Wang, Feihu', 1),
#  ('Wang, Feng', 1),
#  ('Wang, Feng-Chao', 1),
#  ('Wang, H.', 1),
#  ('Wang, Hong-Fei', 1),
#  ('Wang, Hong-fei', 1),
#  ('Wang, Hongfei', 1),
#  ('Wang, Lei', 1),
#  ('Wang, Lijuan', 1),
#  ('Wang, Lingjian', 1),
#  ('Wang, Mao', 1),
#  ('Wang, Michael C.', 1),
#  ('Wang, Pan', 1),
#  ('Wang, Peiming', 1),
#  ('Wang, Ping', 1),
#  ('Wang, Rui', 1),
#  ('Wang, Tao', 1),
#  ('Wang, Weizhou', 1),
#  ('Wang, Wenjie', 1),
#  ('Wang, Xiao-Gang', 1),
#  ('Wang, Xiaohan', 1),
#  ('Wang, Xiaohui', 1),
#  ('Wang, Xiaoyu', 1),
#  ('Wang, Xiluan', 1),
#  ('Wang, Xin', 1),
#  ('Wang, Xinping', 1),
#  ('Wang, Xue-Bin', 1),
#  ('Wang, Yan-Wei', 1),
#  ('Wang, Yang', 1),
#  ('Wang, Yi-Bo', 1),
#  ('Wang, Ying', 1),
#  ('Wang, Yingying', 1),
#  ('Wang, Zhao', 1),
#  ('Wang, Zhen-Gang', 1),
#  ('Wang, Zhuguang', 1),
#  ('Wang, Ziqian', 1),
#  ('Warr, Gregory G.', 1),
#  ('Wassei, Jonathan K.', 1),
#  ('Watanabe, Hidekazu', 1),
#  ('Watanabe, Iwao', 1),
#  ('Watanabe, J.', 1),
#  ('Waychunas, G. A.', 1),
#  ('Webb III, Edmund B.', 1),
#  ('Webb, Simon P.', 1),
#  ('Weber, Jeffrey K.', 1),
#  ('Webster, John R. P.', 1),
#  ('Wee, Andrew Thye Shen', 1),
#  ('Weeks, John D.', 1),
#  ('Weeraman, Champika N.', 1),
#  ('Wegkamp, Daniel', 1),
#  ('Wegmann, A.', 1),
#  ('Wehling, Tim O.', 1),
#  ('Wei, Tai-Huei', 1),
#  ('Wei, Wen-mei', 1),
#  ('Wei, Xing', 1),
#  ('Weinelt, Martin', 1),
#  ('Weinhardt, L.', 1),
#  ('Weinhardt, Lothar', 1),
#  ('Weinheimer, C.', 1),
#  ('Weis, Christoph', 1),
#  ('Weiss, A. H.', 1),
#  ('Weiss, T. M.', 1),
#  ('Weiss, Thomas', 1),
#  ('Weiss, Thomas M.', 1),
#  ('Weiss, Volker C.', 1),
#  ('Weissenborn, Peter K.', 1),
#  ('Welsh, A.H.', 1),
#  ('Wen, Xiewen', 1),
#  ('Wender, Aurélie', 1),
#  ('Werder, T.', 1),
#  ('Wernersson, Erik', 1),
#  ('Wernet, Philippe', 1),
#  ('Wescott, J. T.', 1),
#  ('Wesolowski, David J.', 1),
#  ('Wesolowski, Tomasz A.', 1),
#  ('Westh, Peter', 1),
#  ('Whetten, Robert L.', 1),
#  ('White, Andrew D.', 1),
#  ('White, John W.', 1),
#  ('White, Lee R.', 1),
#  ('Wick, Collin D.', 1),
#  ('Widom, B.', 1),
#  ('Wiersma, Douwe A.', 1),
#  ('Wieser, H.', 1),
#  ('Wijnhoven, Judith E. G. J.', 1),
#  ('Wikfeldt, K. T.', 1),
#  ('Wilcox, David S.', 1),
#  ('Wilford N., Hansen', 1),
#  ('Wilkins, Charles H.', 1),
#  ('Wilkinson, K.', 1),
#  ('Wilkinson, K. M.', 1),
#  ('Wilkinson, Katherine M.', 1),
#  ('Willard, Adam P.', 1),
#  ('Willard, Jesse A.', 1),
#  ('Williams, D.', 1),
#  ('Williams, D. R. M.', 1),
#  ('Williams, Evan R.', 1),
#  ('Williams, G. J.', 1),
#  ('Williams, H. L.', 1),
#  ('Williams, Howard', 1),
#  ('Williams, Owen L.', 1),
#  ('Wilson, Kevin R.', 1),
#  ('Winkelmann, C.\u2009B.', 1),
#  ('Winkelmann, J', 1),
#  ('Winoto, Winoto', 1),
#  ('Winter, Bernd', 1),
#  ('Winterhalder, M. J.', 1),
#  ('Wishart, J.', 1),
#  ('Witherspoon, P. A.', 1),
#  ('Wojciechowski, Kamil', 1),
#  ('Wolf, M.', 1),
#  ('Wolf, Martin', 1),
#  ('Wong, Daryl B.', 1),
#  ('Wong, Dillon', 1),
#  ('Wong, Wing Han', 1),
#  ('Wood, Christopher A.', 1),
#  ('Wood, Joshua D.', 1),
#  ('Wood, Suzannah R.', 1),
#  ('Woodward, Clifford E.', 1),
#  ('Wright, David W.', 1),
#  ('Wu, Bao-Hua', 1),
#  ('Wu, C. H.', 1),
#  ('Wu, H. A.', 1),
#  ('Wu, Hongping', 1),
#  ('Wu, Jianzhong', 1),
#  ('Wu, Jishan', 1),
#  ('Wu, Pan', 1),
#  ('Wu, Qiong', 1),
#  ('Wu, Tzong-Daw', 1),
#  ('Wu, Wei', 1),
#  ('Wu, X. Z.', 1),
#  ('Wu, Xiu-Xia', 1),
#  ('Wu, Yanbin', 1),
#  ('Wu, Yuqing', 1),
#  ('Wu, Zhe', 1),
#  ('Wunderlich, S.', 1),
#  ('Wunderlich, Sarina', 1),
#  ('Wurpel, George W. H.', 1),
#  ('Wyche, Melanie', 1),
#  ('Xantheas, Sotiris S.', 1),
#  ('Xia, Jinjun', 1),
#  ('Xiao, Shunhao', 1),
#  ('Xie, Guoxin', 1),
#  ('Xie, Wen Jun', 1),
#  ('Xie, Wenyi', 1),
#  ('Xie, Zhenhua', 1),
#  ('Xing, Baoshan', 1),
#  ('Xing, Sirui', 1),
#  ('Xiong, Peng', 1),
#  ('Xiong, Wei', 1),
#  ('Xu, Hong-Liang', 1),
#  ('Xu, Jiafang', 1),
#  ('Xu, Ke', 1),
#  ('Xu, Lijun', 1),
#  ('Xu, P.', 1),
#  ('Xu, Siyun', 1),
#  ('Xu, Weiqing', 1),
#  ('Xu, Yan-yan', 1),
#  ('Xu, Yun', 1),
#  ('Xu, Yuntao', 1),
#  ('Xu, Z.', 1),
#  ('Xue, Zhifeng', 1),
#  ('Yadav, Hari Om Sharanam', 1),
#  ('Yagasaki, Takuma', 1),
#  ('Yakobson, Boris I.', 1),
#  ('Yakovlev, V. V.', 1),
#  ('Yakovlev, Vladislav S.', 1),
#  ('Yamada, Hirofumi', 1),
#  ('Yamada, Takashi', 1),
#  ('Yamaguchi, Shoichi', 1),
#  ('Yamamoto, Ryota', 1),
#  ('Yamamoto, Yo-ichi', 1),
#  ('Yamazaki, Kenji', 1),
#  ('Yan, Ci', 1),
#  ('Yan, E.C.Y.', 1),
#  ('Yan, Elsa C. Y.', 1),
#  ('Yan, L.', 1),
#  ('Yan, Wei', 1),
#  ('Yan, Youguo', 1),
#  ('Yanaga, M.', 1),
#  ('Yandell, Margaret A.', 1),
#  ('Yang, Cheolhee', 1),
#  ('Yang, Dah-Yen', 1),
#  ('Yang, Fang', 1),
#  ('Yang, Gang', 1),
#  ('Yang, Guang', 1),
#  ('Yang, Hu', 1),
#  ('Yang, Jingxiu', 1),
#  ('Yang, Lijiang', 1),
#  ('Yang, Mingli', 1),
#  ('Yang, Mino', 1),
#  ('Yang, Tinglu', 1),
#  ('Yang, W.', 1),
#  ('Yang, Wanli', 1),
#  ('Yang, Xiaoguang', 1),
#  ('Yang, Y.', 1),
#  ('Yang, Yanmei', 1),
#  ('Yang, Yi', 1),
#  ('Yang, Zhen', 1),
#  ('Yang, Zhihua', 1),
#  ('Yao, Yongji', 1),
#  ('Yarovsky, Irene', 1),
#  ('Yavari, Fazel', 1),
#  ('Yee, H. I.', 1),
#  ('Yefet, Shai', 1),
#  ('Yeganeh, M. S.', 1),
#  ('Yeganeh, Mohsen', 1),
#  ('Yeh, An-Gong', 1),
#  ('Yeh, Yuh-Lin', 1),
#  ('Yethiraj, Anand', 1),
#  ('Yethiraj, Arun', 1),
#  ('Yezer, Benjamin A.', 1),
#  ('Yiapanis, George', 1),
#  ('Yin, Fuchang', 1),
#  ('Yin, Zhong', 1),
#  ('Yonemitsu, Takeshi', 1),
#  ('Yoo, EunJoo', 1),
#  ('Yoo, Soohaeng', 1),
#  ('Yoshimune, Seiji', 1),
#  ('You, Siheng Sean', 1),
#  ('You, YuMeng', 1),
#  ('Young, Aidan G.', 1),
#  ('Young, Ryan M.', 1),
#  ('Yu, Hao', 1),
#  ('Yu, Hongwei', 1),
#  ('Yu, Jun-Ying', 1),
#  ('Yu, Young-Jun', 1),
#  ('Yu, Zhaoning', 1),
#  ('Yu, Zhenning', 1),
#  ('Yuan, Quanzi', 1),
#  ('Yudhistira, I.', 1),
#  ('Yue, Guojun', 1),
#  ('Yuk, Jong Min', 1),
#  ('Zacharias, Martin', 1),
#  ('Zajforoushan Moghaddam, Saeed', 1),
#  ('Zangi, Ronen', 1),
#  ('Zank, Johann', 1),
#  ('Zanni, Martin T.', 1),
#  ('Zarbakhsh, Ali', 1),
#  ('Zaric, Snezana D.', 1),
#  ('Zaslavsky, Boris Y', 1),
#  ('Zbořil, M.', 1),
#  ('Zeitler, J. Axel', 1),
#  ('Zeng, Xiao Cheng', 1),
#  ('Zentgraf, Thomas', 1),
#  ('Zeppieri, Susana', 1),
#  ('Zerbi, Giuseppe', 1),
#  ('Zettl, A.', 1),
#  ('Zettl, Alex', 1),
#  ('Zeuner, Franziska', 1),
#  ('Zhamu, Aruna', 1),
#  ('Zhang, Dongmao', 1),
#  ('Zhang, Gang', 1),
#  ('Zhang, Han', 1),
#  ('Zhang, Jian', 1),
#  ('Zhang, Jin', 1),
#  ('Zhang, Jun', 1),
#  ('Zhang, Li', 1),
#  ('Zhang, Libo', 1),
#  ('Zhang, Luyuan', 1),
#  ('Zhang, Min', 1),
#  ('Zhang, Qiang', 1),
#  ('Zhang, Ruiting', 1),
#  ('Zhang, Shuang', 1),
#  ('Zhang, Tao', 1),
#  ('Zhang, Wei', 1),
#  ('Zhang, Weiwei', 1),
#  ('Zhang, Wen-kai', 1),
#  ('Zhang, Wenkai', 1),
#  ('Zhang, Yang', 1),
#  ('Zhang, Yanjie', 1),
#  ('Zhang, Ying', 1),
#  ('Zhang, Yong-Wei', 1),
#  ('Zhang, Yu', 1),
#  ('Zhang, Yuanbo', 1),
#  ('Zhang, Yuegang', 1),
#  ('Zhang, Yun', 1),
#  ('Zhang, Yun-Hong', 1),
#  ('Zhang, Zhen', 1),
#  ('Zhang, Zhibing', 1),
#  ('Zhang, Zhiliang', 1),
#  ('Zhao, Bing', 1),
#  ('Zhao, J.', 1),
#  ('Zhao, Qi', 1),
#  ('Zhao, Xiaolin', 1),
#  ('Zhao, Ya-Pu', 1),
#  ('Zhao, Yang', 1),
#  ('Zhao, Zhihong', 1),
#  ('Zharnikov, M.', 1),
#  ('Zharnikov, Michael', 1),
#  ('Zhavoronkov, N.', 1),
#  ('Zheng, De-sheng', 1),
#  ('Zheng, Junrong', 1),
#  ('Zheng, Ren-hui', 1),
#  ('Zheng, Wei-Jun', 1),
#  ('Zheng, Yi Ying', 1),
#  ('Zhong, Dongping', 1),
#  ('Zhong, Rong-Lin', 1),
#  ('Zhou, Hao-shen', 1),
#  ('Zhou, Haoshen', 1),
#  ('Zhou, Hua', 1),
#  ('Zhou, Ruhong', 1),
#  ('Zhou, Xibin', 1),
#  ('Zhou, Xin', 1),
#  ('Zhou, Zhixian', 1),
#  ('Zhu, Chang', 1),
#  ('Zhu, Chongqin', 1),
#  ('Zhu, Hualing', 1),
#  ('Zhu, Xuefeng', 1),
#  ('Zhu, Xueyan', 1),
#  ('Zhu, Yanwu', 1),
#  ('Zhu, Yingxi', 1),
#  ('Zhuang, Wei', 1),
#  ('Zhuang, Xiaowei', 1),
#  ('Zichi, Dominic A.', 1),
#  ('Zielke, Philipp', 1),
#  ('Zimdars, David', 1),
#  ('Zinn-Justin, Jean', 1),
#  ('Zitolo, Andrea', 1),
#  ('Zjawiony, Ireneusz', 1),
#  ('Zoranic, Larisa', 1),
#  ('Zou, Shengli', 1),
#  ('Zukoski, Charles F.', 1),
#  ('Zukowski, Samual R.', 1),
#  ('Zumbusch, A.', 1),
#  ('Zwanikken, Jos', 1),
#  ('Zwanikken, Jos W.', 1),
#  ('da Silva, F. Ferreira', 1),
#  ('da Silva, Juliana Angeiras Batista', 1),
#  ('de Aguiar, H. B.', 1),
#  ('de Aguiar, Hilton B.', 1),
#  ('de Beer, A. G. F.', 1),
#  ('de Beer, Alex G. F.', 1),
#  ('de Beer, Alex GF', 1),
#  ('de Bleijser, Jan', 1),
#  ('de Leeuw, Nora H.', 1),
#  ('de Miguel, Maykel', 1),
#  ('de la Peña, Gilberto A.', 1),
#  ('de, Juan', 1),
#  ('dos Santos, Alexandre P.', 1),
#  ('dos Santos, Maria Cristina', 1),
#  ('dos Santos, Vivianni Marques Leite', 1),
#  ('la Cour Jansen, Thomas', 1),
#  ('nchez-Ponce, Raymundo', 1),
#  ('van Driel, Henry M.', 1),
#  ('van Duin, Adri C. T.', 1),
#  ('van Erp, Titus S.', 1),
#  ('van Gunsteren, Wilfred F.', 1),
#  ('van Heumen, E.', 1),
#  ('van Roij, René', 1),
#  ('van Swol, Frank', 1),
#  ('van den Ende, D.', 1),
#  ('van der Maarel, J.R.C.', 1),
#  ('van der Marel, D.', 1),
#  ('van der Post, Sietse T.', 1),
#  ('van der Post, Sietse Thijmen', 1),
#  ('van der Vegt, Nico F. A.', 1),
#  ('van der Vegt, Nico FA', 1),
#  ('von Klitzing, Regine', 1),
#  ('von Reppert, A.', 1),
#  ('Álvaro, Mercedes', 1),
#  ('Åstrand, Per-Olof', 1),
#  ('Đuričković, Ivana', 1),
#  ('Šafářová, Klára', 1),
#  ('Štrancar, Janez', 1)]
# (('name', None, None, None, None, None, None),
#  ('count', None, None, None, None, None, None))

# %%
#exploring author data more
cur.execute("SELECT t1.itemID, t1.creatorID, t2.creatorType, t4.creatorDataID, t4.firstName, t4.lastName "
            "FROM itemCreators t1 "
            "LEFT JOIN creatorTypes t2 "
            "ON t1.creatorTypeID = t2.creatorTypeID "
            "LEFT JOIN creators t3 "
            "ON t1.creatorID = t3.creatorID "
            "LEFT JOIN creatorData t4 "
            "ON t3.creatorDataID = t4.creatorDataID "
            "WHERE t3.creatorID != t4.creatorDataID "
            "AND t2.creatorType != 'author' "
            "ORDER BY t1.itemID, t1.creatorID, t4.creatorDataID "
            "LIMIT 20"
           )
item_and_authors_test3 = cur.fetchall()
pprint.pprint(item_and_authors_test3)
cur.description
# Out:
# [(1557, 1343, 'contributor', 1342, 'R. H.', 'Stokes'),
#  (1730, 1445, 'contributor', 1444, 'Mark', 'Schlossman'),
#  (1765, 1554, 'editor', 1553, 'J.', 'Charvolin'),
#  (1765, 1555, 'editor', 1554, 'J. F.', 'Joanny'),
#  (1765, 1556, 'editor', 1555, 'Jean', 'Zinn-Justin'),
#  (1903, 1785, 'editor', 1784, 'Clive A.', 'Croxton'),
#  (2361, 2390, 'editor', 2389, 'Clarence A.', 'Miller'),
#  (2361, 2391, 'editor', 2390, 'P.', 'Neogi'),
#  (2404, 2462, 'editor', 2461, 'David L.', 'Andrews'),
#  (2404, 2463, 'editor', 2462, 'Guozhong Z.', 'Cao'),
#  (2404, 2464, 'editor', 2463, 'Zeno', 'Gaburro'),
#  (2902, 3310, 'editor', 3309, 'Philip J.', 'Brown'),
#  (2902, 3311, 'editor', 3310, 'Wayne A.', 'Fuller'),
#  (2902, 3312, 'editor', 3311, '', 'American Mathematical Society'),
#  (2902, 3313, 'editor', 3312, '', 'Institute of Mathematical Statistics'),
#  (2902,
#   3314,
#   'editor',
#   3313,
#   '',
#   'Society for Industrial and Applied Mathematics'),
#  (3086, 3276, 'programmer', 3275, 'Alan', 'Grossfield')]
# (('itemID', None, None, None, None, None, None),
#  ('creatorID', None, None, None, None, None, None),
#  ('creatorType', None, None, None, None, None, None),
#  ('creatorDataID', None, None, None, None, None, None),
#  ('firstName', None, None, None, None, None, None),
#  ('lastName', None, None, None, None, None, None))

# %% [markdown]
# `creatorID` and `creatorDataID` seem to serve the same function, but they are not always equal. I'm not sure what the difference is. `itemID` seems to be the aggregate identifier for items with more than one creator.

# %%
cur.execute("SELECT t4.lastName || ', ' || t4.firstName AS name, "
            "COUNT(t4.lastName || ', ' || t4.firstName) AS count "
            "FROM itemCreators t1 "
            "LEFT JOIN creatorTypes t2 "
            "ON t1.creatorTypeID = t2.creatorTypeID "
            "LEFT JOIN creators t3 "
            "ON t1.creatorID = t3.creatorID "
            "LEFT JOIN creatorData t4 "
            "ON t3.creatorDataID = t4.creatorDataID "
            "GROUP BY name "
            "HAVING count > 5 "
            "ORDER BY count DESC"
           )
author_count = cur.fetchall()
pprint.pprint(author_count)
cur.description
# Out:
# [('Roke, Sylvie', 28),
#  ('Jungwirth, Pavel', 23),
#  ('Saykally, Richard J.', 21),
#  ('Allen, Heather C.', 18),
#  ('Ben-Amotz, Dor', 17),
#  ('Tahara, Tahei', 15),
#  ('Yamaguchi, Shoichi', 15),
#  ('Bakker, Huib J.', 13),
#  ('Chandler, David', 13),
#  ('Tobias, Douglas J.', 13),
#  ('Bonn, Mischa', 12),
#  ('Petersen, Poul B.', 12),
#  ('Richmond, Geraldine L.', 12),
#  ('Hua, Wei', 11),
#  ('Netz, Roland R.', 9),
#  ('de Beer, Alex G. F.', 9),
#  ('Backus, Ellen H. G.', 8),
#  ('Bain, Colin D.', 8),
#  ('Cremer, Paul S.', 8),
#  ('Deutsch, M.', 8),
#  ('Garde, Shekhar', 8),
#  ('Geissler, Phillip L.', 8),
#  ('Horinek, Dominik', 8),
#  ('Jena, Kailash C.', 8),
#  ('Marcus, Yizhak', 8),
#  ('Matsuura, Hiroatsu', 8),
#  ('Baer, Marcel D.', 7),
#  ('Benjamin, Ilan', 7),
#  ('Bonn, Daniel', 7),
#  ('Geiger, Franz M.', 7),
#  ('Laage, Damien', 7),
#  ('Levin, Yan', 7),
#  ('Nihonyanagi, Satoshi', 7),
#  ('Rankin, Blake M.', 7),
#  ('Scheu, Rüdiger', 7),
#  ('Verreault, Dominique', 7),
#  ('Vácha, Robert', 7),
#  ('Wang, Feng', 7),
#  ('Willard, Adam P.', 7),
#  ('Bluhm, Hendrik', 6),
#  ('Campen, R. Kramer', 6),
#  ('Eisenthal, Kenneth B.', 6),
#  ('Hemminger, John C.', 6),
#  ('Morita, Akihiro', 6),
#  ('Mundy, Christopher J.', 6),
#  ('Patel, Sandeep', 6),
#  ('Salmeron, Miquel', 6),
#  ('Zettl, Alex', 6),
#  ('de Aguiar, Hilton B.', 6)]
# (('name', None, None, None, None, None, None),
#  ('count', None, None, None, None, None, None))

# %% [markdown]
# Names that I do not recognize:
# * Yamaguchi, Shoichi
# * Hua, Wei
# * Deutsch, M.
# * Garde, Shekhar
# * Horinek, Dominik
# * Jena, Kailash C.
# * Marcus, Yizhak
# * Nihonyanagi, Satoshi
# * Scheu, Rüdiger
# * Campen, R. Kramer
# * Morita, Akihiro
# * Mundy, Christopher J.
#
# Most of the names I recognize are professors. It could be that these names are students.

# %%
names = ["Yamaguchi, Shoichi",
        "Hua, Wei",
        "Deutsch, M.",
        "Garde, Shekhar",
        "Horinek, Dominik",
        "Jena, Kailash C.",
        "Marcus, Yizhak",
        "Nihonyanagi, Satoshi",
        "Scheu, Rüdiger",
        "Campen, R. Kramer",
        "Morita, Akihiro",
        "Mundy, Christopher J."]

# %%
person = ("Yamaguchi, Shoichi","Yamaguchi, Shoichi")
cur.execute("SELECT t1.itemID, t4.lastName || ', ' || t4.firstName AS name "
            "FROM itemCreators t1 "
            "LEFT JOIN creatorTypes t2 "
            "ON t1.creatorTypeID = t2.creatorTypeID "
            "LEFT JOIN creators t3 "
            "ON t1.creatorID = t3.creatorID "
            "LEFT JOIN creatorData t4 "
            "ON t3.creatorDataID = t4.creatorDataID "
            "WHERE name != ?"
            "AND t1.itemID IN ("
                                "SELECT t1.itemID "
                                "FROM itemCreators t1 "
                                "LEFT JOIN creatorTypes t2 "
                                "ON t1.creatorTypeID = t2.creatorTypeID "
                                "LEFT JOIN creators t3 "
                                "ON t1.creatorID = t3.creatorID "
                                "LEFT JOIN creatorData t4 "
                                "ON t3.creatorDataID = t4.creatorDataID "
                                "WHERE t4.lastName || ', ' || t4.firstName = ?)",
            person)
coauthors = cur.fetchall()
pprint.pprint(coauthors)
# Out:
# [(560, 'Tahara, Tahei'),
#  (867, 'Tahara, Tahei'),
#  (867, 'Mondal, Sudip Kumar'),
#  (897, 'Tahara, Tahei'),
#  (897, 'Mondal, Sudip Kumar'),
#  (897, 'Watanabe, Hidekazu'),
#  (897, 'Kundu, Achintya'),
#  (906, 'Tahara, Tahei'),
#  (906, 'Bhattacharyya, Kankan'),
#  (910, 'Tahara, Tahei'),
#  (910, 'Shiratori, Kazuya'),
#  (910, 'Morita, Akihiro'),
#  (1004, 'Tahara, Tahei'),
#  (1007, 'Tahara, Tahei'),
#  (1007, 'Watanabe, Hidekazu'),
#  (1007, 'Morita, Akihiro'),
#  (1007, 'Sen, Sobhan'),
#  (1116, 'Tahara, Tahei'),
#  (1116, 'Kundu, Achintya'),
#  (1116, 'Sen, Pratik'),
#  (1384, 'Tahara, Tahei'),
#  (1384, 'Nihonyanagi, Satoshi'),
#  (1384, 'Mondal, Jahur A.'),
#  (1774, 'Tahara, Tahei'),
#  (1774, 'Nihonyanagi, Satoshi'),
#  (2218, 'Tahara, Tahei'),
#  (2218, 'Bonn, Mischa'),
#  (2218, 'Morita, Akihiro'),
#  (2218, 'Nihonyanagi, Satoshi'),
#  (2218, 'Ishiyama, Tatsuya'),
#  (2218, 'Lee, Touk-kwan'),
#  (2519, 'Tahara, Tahei'),
#  (2519, 'Nihonyanagi, Satoshi'),
#  (2944, 'Tahara, Tahei'),
#  (2944, 'Nihonyanagi, Satoshi'),
#  (2944, 'Matsuzaki, Korenobu'),
#  (2944, 'Kusaka, Ryoji'),
#  (2944, 'Nagata, Takashi'),
#  (2980, 'Tahara, Tahei'),
#  (2980, 'Nihonyanagi, Satoshi'),
#  (2980, 'Mondal, Jahur A.'),
#  (3029, 'Tahara, Tahei'),
#  (3029, 'Kundu, Achintya'),
#  (3029, 'Morita, Akihiro'),
#  (3029, 'Nihonyanagi, Satoshi'),
#  (3029, 'Ahmed, Mohammed'),
#  (3029, 'Ishiyama, Tatsuya'),
#  (3029, 'Tanaka, Shogo'),
#  (3029, 'Inoue, Ken-ichi'),
#  (3029, 'Sawai, Hiromi')]

# %%
all_coathors = []
for author in names:
    person = (author,author)
    cur.execute("SELECT t1.itemID, t4.lastName || ', ' || t4.firstName AS name "
            "FROM itemCreators t1 "
            "LEFT JOIN creatorTypes t2 "
            "ON t1.creatorTypeID = t2.creatorTypeID "
            "LEFT JOIN creators t3 "
            "ON t1.creatorID = t3.creatorID "
            "LEFT JOIN creatorData t4 "
            "ON t3.creatorDataID = t4.creatorDataID "
            "WHERE name != ?"
            "AND t1.itemID IN ("
                                "SELECT t1.itemID "
                                "FROM itemCreators t1 "
                                "LEFT JOIN creatorTypes t2 "
                                "ON t1.creatorTypeID = t2.creatorTypeID "
                                "LEFT JOIN creators t3 "
                                "ON t1.creatorID = t3.creatorID "
                                "LEFT JOIN creatorData t4 "
                                "ON t3.creatorDataID = t4.creatorDataID "
                                "WHERE t4.lastName || ', ' || t4.firstName = ?)",
            person)
    coauthors = cur.fetchall()
    all_coathors.append([author, coauthors])
all_coathors
# Out:
# [['Yamaguchi, Shoichi',
#   [(560, 'Tahara, Tahei'),
#    (867, 'Tahara, Tahei'),
#    (867, 'Mondal, Sudip Kumar'),
#    (897, 'Tahara, Tahei'),
#    (897, 'Mondal, Sudip Kumar'),
#    (897, 'Watanabe, Hidekazu'),
#    (897, 'Kundu, Achintya'),
#    (906, 'Tahara, Tahei'),
#    (906, 'Bhattacharyya, Kankan'),
#    (910, 'Tahara, Tahei'),
#    (910, 'Shiratori, Kazuya'),
#    (910, 'Morita, Akihiro'),
#    (1004, 'Tahara, Tahei'),
#    (1007, 'Tahara, Tahei'),
#    (1007, 'Watanabe, Hidekazu'),
#    (1007, 'Morita, Akihiro'),
#    (1007, 'Sen, Sobhan'),
#    (1116, 'Tahara, Tahei'),
#    (1116, 'Kundu, Achintya'),
#    (1116, 'Sen, Pratik'),
#    (1384, 'Tahara, Tahei'),
#    (1384, 'Nihonyanagi, Satoshi'),
#    (1384, 'Mondal, Jahur A.'),
#    (1774, 'Tahara, Tahei'),
#    (1774, 'Nihonyanagi, Satoshi'),
#    (2218, 'Tahara, Tahei'),
#    (2218, 'Bonn, Mischa'),
#    (2218, 'Morita, Akihiro'),
#    (2218, 'Nihonyanagi, Satoshi'),
#    (2218, 'Ishiyama, Tatsuya'),
#    (2218, 'Lee, Touk-kwan'),
#    (2519, 'Tahara, Tahei'),
#    (2519, 'Nihonyanagi, Satoshi'),
#    (2944, 'Tahara, Tahei'),
#    (2944, 'Nihonyanagi, Satoshi'),
#    (2944, 'Matsuzaki, Korenobu'),
#    (2944, 'Kusaka, Ryoji'),
#    (2944, 'Nagata, Takashi'),
#    (2980, 'Tahara, Tahei'),
#    (2980, 'Nihonyanagi, Satoshi'),
#    (2980, 'Mondal, Jahur A.'),
#    (3029, 'Tahara, Tahei'),
#    (3029, 'Kundu, Achintya'),
#    (3029, 'Morita, Akihiro'),
#    (3029, 'Nihonyanagi, Satoshi'),
#    (3029, 'Ahmed, Mohammed'),
#    (3029, 'Ishiyama, Tatsuya'),
#    (3029, 'Tanaka, Shogo'),
#    (3029, 'Inoue, Ken-ichi'),
#    (3029, 'Sawai, Hiromi')]],
#  ['Hua, Wei',
#   [(684, 'Chen, Xiangke'),
#    (684, 'Allen, Heather C.'),
#    (747, 'Allen, Heather C.'),
#    (747, 'Jubb, Aaron M.'),
#    (751, 'Allen, Heather C.'),
#    (751, 'Jubb, Aaron M.'),
#    (881, 'Allen, Heather C.'),
#    (881, 'Jubb, Aaron M.'),
#    (1930, 'Allen, Heather C.'),
#    (1930, 'Verreault, Dominique'),
#    (1970, 'Allen, Heather C.'),
#    (1970, 'Verreault, Dominique'),
#    (1970, 'Huang, Zishuai'),
#    (1970, 'Adams, Ellen M.'),
#    (2044, 'Allen, Heather C.'),
#    (2044, 'Verreault, Dominique'),
#    (2044, 'Huang, Zishuai'),
#    (2044, 'Adams, Ellen M.'),
#    (2488, 'Allen, Heather C.'),
#    (2488, 'Verreault, Dominique'),
#    (2502, 'Allen, Heather C.'),
#    (2502, 'Verreault, Dominique'),
#    (2587, 'Allen, Heather C.'),
#    (2587, 'Verreault, Dominique'),
#    (2621, 'de Beer, Alex G. F.'),
#    (2621, 'Roke, Sylvie'),
#    (2621, 'Chen, Xiangke'),
#    (2621, 'Allen, Heather C.'),
#    (2621, 'Huang, Zishuai'),
#    (2621, 'Samson, Jean-Sebastièn')]],
#  ['Deutsch, M.',
#   [(1675, 'Sloutskin, E.'),
#    (1675, 'Sapir, Z.'),
#    (1675, 'Tamam, L.'),
#    (1675, 'Ocko, B.M.'),
#    (1675, 'Bain, C.D.'),
#    (1702, 'Braslau, A.'),
#    (1702, 'Pershan, P. S.'),
#    (1702, 'Weiss, A. H.'),
#    (1988, 'Sloutskin, E.'),
#    (1988, 'Sapir, Z.'),
#    (1988, 'Tamam, L.'),
#    (1988, 'Ocko, B.'),
#    (1988, 'Bain, C.'),
#    (1988, 'Lei, Q.'),
#    (1988, 'Wilkinson, K.'),
#    (2007, 'Wu, X. Z.'),
#    (2007, 'Ocko, B. M.'),
#    (2007, 'Tang, H.'),
#    (2007, 'Sirota, E. B.'),
#    (2007, 'Sinha, S. K.'),
#    (2009, 'Wu, X. Z.'),
#    (2009, 'Ocko, B. M.'),
#    (2009, 'Sirota, E. B.'),
#    (2009, 'Sinha, S. K.'),
#    (2009, 'Gang, O.'),
#    (2026, 'Wu, X. Z.'),
#    (2026, 'Ocko, B. M.'),
#    (2026, 'Sirota, E. B.'),
#    (2026, 'Sinha, S. K.'),
#    (2355, 'Sloutskin, E.'),
#    (2355, 'Wu, X. Z.'),
#    (2355, 'Ocko, B. M.'),
#    (2355, 'Sirota, E. B.'),
#    (2355, 'Gang, O.'),
#    (2355, 'Peterson, T. B.'),
#    (2357, 'Sloutskin, E.'),
#    (2357, 'Ocko, B. M.'),
#    (2357, 'Sirota, E. B.'),
#    (2357, 'Gang, O.'),
#    (2357, 'Kraack, H.'),
#    (2357, 'Doerr, A.')]],
#  ['Garde, Shekhar',
#   [(1256, 'Chandler, David'),
#    (1256, 'Patel, Amish J.'),
#    (1256, 'Varilly, Patrick'),
#    (1256, 'Jamadagni, Sumanth N.'),
#    (1256, 'Acharya, Hari'),
#    (1459, 'Patel, Amish J.'),
#    (1459, 'Vembanur, Srivathsan'),
#    (1459, 'Sarupria, Sapna'),
#    (1761, 'Vembanur, Srivathsan'),
#    (1761, 'Venkateshwaran, Vasudevan'),
#    (2194, 'Jamadagni, Sumanth N.'),
#    (2194, 'Godawat, Rahul'),
#    (2196, 'Chandler, David'),
#    (2196, 'Patel, Amish J.'),
#    (2196, 'Varilly, Patrick'),
#    (2196, 'Jamadagni, Sumanth N.'),
#    (2196, 'Hagan, Michael F.'),
#    (2264, 'Patel, Harshit A.'),
#    (2264, 'Nauman, E. Bruce'),
#    (2312, 'Rajamani, Sowmianarayanan'),
#    (2312, 'Truskett, Thomas M.'),
#    (2514, 'Jamadagni, Sumanth N.'),
#    (2514, 'Godawat, Rahul')]],
#  ['Horinek, Dominik',
#   [(889, 'Netz, Roland R.'),
#    (1716, 'Sedlmeier, Felix'),
#    (1716, 'Netz, Roland'),
#    (2050, 'Vrbka, Lubos'),
#    (2050, 'Netz, Roland R.'),
#    (2050, 'Sedlmeier, Felix'),
#    (2050, 'Herz, Alexander'),
#    (2050, 'Mamatkulov, Shavkat I.'),
#    (2108, 'Netz, Roland R.'),
#    (2108, 'Schwierz, Nadine'),
#    (2110, 'Netz, Roland R.'),
#    (2110, 'Schwierz, Nadine'),
#    (2228, 'Netz, Roland R.'),
#    (2228, 'Schwierz, Nadine'),
#    (2759, 'Jungwirth, Pavel'),
#    (2759, 'Vácha, Robert'),
#    (2759, 'Berkowitz, Max L.'),
#    (2867, 'Pontoni, Diego'),
#    (2867, 'Reichert, Harald'),
#    (2867, 'Sedlmeier, Felix'),
#    (2867, 'Mezger, Markus'),
#    (2867, 'Dosch, Helmut')]],
#  ['Jena, Kailash C.',
#   [(1888, 'Roy, Sandra'),
#    (1888, 'Hore, Dennis K.'),
#    (1888, 'Hall, Shaun A.'),
#    (1888, 'Covert, Paul A.'),
#    (1888, 'Trudeau, Travis G.'),
#    (1924, 'Hore, Dennis K.'),
#    (1924, 'Covert, Paul A.'),
#    (2054, 'Roke, Sylvie'),
#    (2054, 'Scheu, Rüdiger'),
#    (2397, 'Hore, Dennis K.'),
#    (2397, 'Covert, Paul A.'),
#    (2490, 'Ben-Amotz, Dor'),
#    (2490, 'Roke, Sylvie'),
#    (2490, 'Rankin, Blake M.'),
#    (2490, 'Scheu, Rüdiger'),
#    (2490, 'Chen, Yixing'),
#    (2494, 'de Beer, Alex G. F.'),
#    (2494, 'de Aguiar, Hilton B.'),
#    (2494, 'Roke, Sylvie'),
#    (2494, 'Scheu, Rüdiger'),
#    (2619, 'Roke, Sylvie'),
#    (2619, 'Okur, Halil I.'),
#    (2619, 'Chen, Yixing'),
#    (2619, 'Lütgebaucks, Cornelis'),
#    (2966, 'Roke, Sylvie'),
#    (2966, 'Brown, Matthew A.'),
#    (2966, 'Chen, Yixing'),
#    (2966, 'Smolentsev, Nikolay')]],
#  ['Marcus, Yizhak',
#   [(1046, 'Hefter, Glenn'), (2280, 'Jenkins, H. Donald B.')]],
#  ['Nihonyanagi, Satoshi',
#   [(1384, 'Yamaguchi, Shoichi'),
#    (1384, 'Tahara, Tahei'),
#    (1384, 'Mondal, Jahur A.'),
#    (1774, 'Yamaguchi, Shoichi'),
#    (1774, 'Tahara, Tahei'),
#    (2218, 'Yamaguchi, Shoichi'),
#    (2218, 'Tahara, Tahei'),
#    (2218, 'Bonn, Mischa'),
#    (2218, 'Morita, Akihiro'),
#    (2218, 'Ishiyama, Tatsuya'),
#    (2218, 'Lee, Touk-kwan'),
#    (2519, 'Yamaguchi, Shoichi'),
#    (2519, 'Tahara, Tahei'),
#    (2944, 'Yamaguchi, Shoichi'),
#    (2944, 'Tahara, Tahei'),
#    (2944, 'Matsuzaki, Korenobu'),
#    (2944, 'Kusaka, Ryoji'),
#    (2944, 'Nagata, Takashi'),
#    (2980, 'Yamaguchi, Shoichi'),
#    (2980, 'Tahara, Tahei'),
#    (2980, 'Mondal, Jahur A.'),
#    (3029, 'Yamaguchi, Shoichi'),
#    (3029, 'Tahara, Tahei'),
#    (3029, 'Kundu, Achintya'),
#    (3029, 'Morita, Akihiro'),
#    (3029, 'Ahmed, Mohammed'),
#    (3029, 'Ishiyama, Tatsuya'),
#    (3029, 'Tanaka, Shogo'),
#    (3029, 'Inoue, Ken-ichi'),
#    (3029, 'Sawai, Hiromi')]],
#  ['Scheu, Rüdiger',
#   [(1778, 'Ben-Amotz, Dor'),
#    (1778, 'de Aguiar, Hilton B.'),
#    (1778, 'Roke, Sylvie'),
#    (1778, 'Rankin, Blake M.'),
#    (1778, 'Chen, Yixing'),
#    (2054, 'Roke, Sylvie'),
#    (2054, 'Jena, Kailash C.'),
#    (2441, 'Rick, Steven W.'),
#    (2441, 'Roke, Sylvie'),
#    (2441, 'Samson, Jean-Sebastién'),
#    (2441, 'Smolentsev, Nikolay'),
#    (2490, 'Ben-Amotz, Dor'),
#    (2490, 'Roke, Sylvie'),
#    (2490, 'Rankin, Blake M.'),
#    (2490, 'Chen, Yixing'),
#    (2490, 'Jena, Kailash C.'),
#    (2492, 'Roke, Sylvie'),
#    (2492, 'Chen, Yixing'),
#    (2492, 'Subinya, Mireia'),
#    (2494, 'de Beer, Alex G. F.'),
#    (2494, 'de Aguiar, Hilton B.'),
#    (2494, 'Roke, Sylvie'),
#    (2494, 'Jena, Kailash C.'),
#    (2661, 'Roke, Sylvie')]],
#  ['Campen, R. Kramer',
#   [(595, 'Vila Verde, Ana'),
#    (1023, 'Vila Verde, Ana'),
#    (1023, 'Bolhuis, Peter G.'),
#    (1550, 'Backus, Ellen H. G.'),
#    (1550, 'Bonn, Mischa'),
#    (1550, 'Hsieh, Cho-Shuen'),
#    (1550, 'Okuno, Masanari'),
#    (1550, 'Nagata, Yuki'),
#    (2412, 'de Beer, Alex G. F.'),
#    (2412, 'Roke, Sylvie'),
#    (2453, 'Bakker, Huib J.'),
#    (2453, 'Bonn, Mischa'),
#    (2453, 'Sovago, Maria'),
#    (2453, 'Wurpel, George W. H.'),
#    (2453, 'Müller, Michiel'),
#    (3091, 'Wang, Hong-fei'),
#    (3091, 'Borguet, Eric'),
#    (3091, 'Zheng, De-sheng')]],
#  ['Morita, Akihiro',
#   [(910, 'Yamaguchi, Shoichi'),
#    (910, 'Tahara, Tahei'),
#    (910, 'Shiratori, Kazuya'),
#    (1007, 'Yamaguchi, Shoichi'),
#    (1007, 'Tahara, Tahei'),
#    (1007, 'Watanabe, Hidekazu'),
#    (1007, 'Sen, Sobhan'),
#    (2046, 'Hynes, James T.'),
#    (2218, 'Yamaguchi, Shoichi'),
#    (2218, 'Tahara, Tahei'),
#    (2218, 'Bonn, Mischa'),
#    (2218, 'Nihonyanagi, Satoshi'),
#    (2218, 'Ishiyama, Tatsuya'),
#    (2218, 'Lee, Touk-kwan'),
#    (2447, 'Kikkawa, Nobuaki'),
#    (2447, 'Wang, Lingjian'),
#    (3029, 'Yamaguchi, Shoichi'),
#    (3029, 'Tahara, Tahei'),
#    (3029, 'Kundu, Achintya'),
#    (3029, 'Nihonyanagi, Satoshi'),
#    (3029, 'Ahmed, Mohammed'),
#    (3029, 'Ishiyama, Tatsuya'),
#    (3029, 'Tanaka, Shogo'),
#    (3029, 'Inoue, Ken-ichi'),
#    (3029, 'Sawai, Hiromi')]],
#  ['Mundy, Christopher J.',
#   [(1650, 'Baer, Marcel D.'),
#    (1798, 'Baer, Marcel D.'),
#    (1798, 'Tobias, Douglas J.'),
#    (1798, 'Levin, Yan'),
#    (1798, 'Stern, Abraham C.'),
#    (1964, 'Baer, Marcel D.'),
#    (1964, 'Fulton, John L.'),
#    (1964, 'Balasubramanian, Mahalingam'),
#    (1964, 'Schenter, Gregory K.'),
#    (1972, 'Baer, Marcel D.'),
#    (1972, 'Tobias, Douglas J.'),
#    (1972, 'Kuo, I-Feng W.'),
#    (2811, 'Baer, Marcel D.'),
#    (2918, 'Baer, Marcel D.'),
#    (2918, 'Tobias, Douglas J.'),
#    (2918, 'Stern, Abraham C.')]]]

# %% [markdown]
# As I suspected, most of these are students under a name I do recognize. For example, Shoichi Yamaguchi's papers all have Tahei Tahara as a coauthor. Tahei Tahara is a Japanese professor who does work on visible SFG experiments. Some of the names do not appear to be students though, and warrant further investigation:
# * Garde, Shekhar - papers with many groups
# * Jena, Kailash C. - papers with Hore and Roke
# * Marcus, Yizhak - only has two papers with coauthors, but appears 8 times
# * Campen, R. Kramer - papers with many groups

# %% [markdown]
# Shekar Garde is a professor at Rensselaer Polytechnic Institute. His research is in theoretical simulations of water. I will have to look further at his work. Kailash Jena has worked for two professors I recognize and is now a professor himself. I will keep an eye out for his future work. Yizhak Marcus authored (on his own) many papers I use for physical properties. Kramer Campen is a spectroscopist who worked with several professors I follow, but he has his own research group now that is not as relevant to my work.

# %%
zotero.close()
